# %%
import networkx as nx # for graph representation, here it is used for rank awarding for textrank. 
import numpy as np    # for array/matrix creation
from nltk.corpus import stopwords # loading stopwords from nltk.corpus toolkit 
from nltk.stem import WordNetLemmatizer # for stemming WordNetLemmatizer is used
from nltk.tokenize import sent_tokenize, word_tokenize # for tokenizing sentences and words using nltk.tokenize 
from sklearn.metrics.pairwise import cosine_similarity # calculating cosiner similarity
from sklearn.cluster import KMeans #for kmean clustering purpose. 
from scipy.spatial import distance # for finding the euclidean distance for clustering in kmeans
from evaluate import load # evaluation using metrics
# Load the ROUGE metric
import evaluate 
import pandas as pd # for dataframe creation
import re # regular expression usage
import os # file/ folder handling
import matplotlib.pyplot as plt # plotting graphs
from sklearn.feature_extraction.text import CountVectorizer
import seaborn as sns # for heatmap creation
import numpy as np

wl = WordNetLemmatizer()

def reading_text(filepath) -> str:
    #print("Reading text")
    with open(filepath, 'rt',encoding='utf-8') as file1:
        temp = file1.read()
        #temp = re.sub('[^a-zA-Z0-9£₹]', " ", temp)
        raw_report = temp.lower()
    return raw_report

def extract_word_vectors() -> dict:
    """
    Extracting word embeddings. These are the n vector representation of words.
    """
    #print('Extracting word vectors')

    word_embeddings = {}
    # Here we use glove word embeddings of 100 dimension
    f = open('glove.6B.100d.txt', encoding='utf-8')
    for line in f:
        values = line.split()
        word = values[0]
        coefs = np.asarray(values[1:], dtype='float32')
        word_embeddings[word] = coefs

    f.close()
    return word_embeddings


def text_preprocessing(sentences: list) -> list:
    """
    Pre processing text to remove unnecessary words.
    """
    #print('Preprocessing text')

    stop_words = set(stopwords.words('english'))
    for i in range(len(sentences)):
        sen = re.sub('[^a-zA-Z0-9£₹]', " ", sentences[i])  
        #sen = sen.lower()  
        sen=sentences[i]
        sen=sen.split()                         
        sen = ' '.join([i for i in sen if i not in stopwords.words('english')])
        sentences.append(sen)


    clean_words = None
    for sent in sentences:
        words = word_tokenize(sent)
        #words = [wl.lemmatize(word.lower()) for word in words if word.isalnum()]
        clean_words = [word for word in words if word not in stop_words]

    return clean_words


def sentence_vector_representation(sentences: list, word_embeddings: dict) -> list:
    """
    Creating sentence vectors from word embeddings.
    """
    #print('Sentence embedding vector representations')

    sentence_vectors = []
    for sent in sentences:
        clean_words = text_preprocessing([sent])
        # Averaging the sum of word embeddings of the sentence to get sentence embedding vector
        v = sum([word_embeddings.get(word, np.zeros(100, )) for word in clean_words]) / (len(clean_words) + 0.001)
        sentence_vectors.append(v)

    return sentence_vectors


def create_similarity_matrix(sentences: list, sentence_vectors: list) -> np.ndarray:
    """
    Using cosine similarity, generate similarity matrix.
    """
    #print('Creating similarity matrix')
     # Vectorize sentences
    vectorizer = CountVectorizer()
    X = vectorizer.fit_transform(sentences)
    
    # Calculate cosine similarity between sentence vectors
    sim_mat = cosine_similarity(X, X)
    # Defining a zero matrix of dimension n * n
    #sim_mat = np.zeros([len(sentences), len(sentences)])
    #for i in range(len(sentences)):
    #    for j in range(len(sentences)):
    #        if i != j:
    #            # Replacing array value with similarity value.
    #            # Not replacing the diagonal values because it represents similarity with its own sentence.
    #            sim_mat[i][j] = cosine_similarity(sentence_vectors[i].reshape(1, 100), sentence_vectors[j].reshape(1, 100))[0, 0]

    return sim_mat


def determine_sentence_rank(sentences: list, sim_mat: np.ndarray):
    """
    Determining sentence rank using Page Rank algorithm.
    """
    #print('Determining sentence ranks')
    nx_graph = nx.from_numpy_array(sim_mat)
    scores = nx.pagerank(nx_graph)
    ranked_sentences = sorted([(scores[i], s[:15]) for i, s in enumerate(sentences)], reverse=True)
    return ranked_sentences


def generate_summary_textrank(sentences: list, ranked_sentences: list):
    """
    Generate a sentence for sentence score greater than average.
    """
    #print('Generating summary')

    # Get top 1/3 th ranked sentences
    top_ranked_sentences = ranked_sentences[:int(len(sentences) / 3)] if len(sentences) >= 3 else ranked_sentences

    sentence_count = 0
    summary = ''

    for i in sentences:
        for j in top_ranked_sentences:
            if i[:15] == j[1]:
                summary += i + ' '
                sentence_count += 1
                break
    #summary = ''.join(summary.split())
    return summary

def generate_summary_kmeans(sentences_textrank: list, sen_vectors_textrank: list)->str:
    # Calculate WCSS for different values of n_clusters
    #wcss = []
    #for i in range(1, 11):
    #    kmeans = KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=10, random_state=0)
    #    kmeans.fit(sen_vectors_textrank)
    #    wcss.append(kmeans.inertia_)

    # Calculate the differences between consecutive WCSS values
    #differences = np.diff(wcss)

    # Calculate the percentage change in WCSS
    #percent_change = (differences / wcss[:-1]) * 100

    # Find the index corresponding to the maximum percentage change
    #optimal_index = np.argmax(percent_change)

    # Plot the elbow curve
    #plt.plot(range(1, 11), wcss, marker='o', linestyle='--')
    #plt.title('Elbow Method')
    #plt.xlabel('Number of clusters (n_clusters)')
    #plt.ylabel('Within-cluster sum of squares (WCSS)')
    #plt.show()

    # The optimal value for n_clusters is one more than the index with maximum percentage change
    optimal_n_clusters = 8 #optimal_index + 1
    #print("Optimal number of clusters (n_clusters):", optimal_n_clusters)
    n_clusters = optimal_n_clusters # int(input("Number of clusters: "))
    kmeans = KMeans(n_clusters, init = 'k-means++', random_state = 42)
    y_kmeans = kmeans.fit_predict(sen_vectors_textrank)

    #finding and printing the nearest sentence vector from cluster centroid

    my_list=[]
    for i in range(n_clusters):
        my_dict={}
    
        for j in range(len(y_kmeans)):
            if y_kmeans[j]==i:
                my_dict[j] =  distance.euclidean(kmeans.cluster_centers_[i],sen_vectors_textrank[j])
        #min_distance = min(my_dict.values())
        #my_list.append(min(my_dict, key=my_dict.get))
        min_distances = sorted(my_dict.values())[:4]  # Select only 4 sentences from each cluster
        selected_indices = [index for index, distance_value in my_dict.items() if distance_value in min_distances]
        my_list.extend(selected_indices)
    print(f'No. of sentences in the kmeans:{len(my_list)}\n')
    summary_kmeans = ''.join(sentences_textrank[i] for i in sorted(my_list))
    #summary_kmeans = ''.join(summary_kmeans.split())
    return summary_kmeans


def main():
    directory_path_read = "C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/annual_reports"
    directory_path_write= "C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/"
    for filename in os.listdir(directory_path_read):
        if filename.endswith(".txt"):
            filepath = os.path.join(directory_path_read, filename)
            text = reading_text(filepath)
            #print('Original Text::-----------------\n')

            sentences = sent_tokenize(text.strip())
            #print('Sentences:---------------------\n',sentences)

            word_embeddings = extract_word_vectors()
            #print('Word embeddings:---------------------\n',len(word_embeddings))

            sentence_vectors = sentence_vector_representation(sentences, word_embeddings)
            #print('Sentence vectors:--------------------\n', len(sentence_vectors), sentence_vectors)

            sim_mat = create_similarity_matrix(sentences, sentence_vectors)
            #print('Similarity matrix:-------------------\n', sim_mat.shape, sim_mat)

            ranked_sentences = determine_sentence_rank(sentences, sim_mat)
            #print('Length of Ranked Sentences-------------\n', len(ranked_sentences))
            #print('Ranked sentences:--------------------\n', ranked_sentences)

            summary = generate_summary_textrank(sentences, ranked_sentences)
            #print('Length of summary after TestRank-------------\n', len(summary))
            #print('Summary generated by TextRank--------------------\n',summary)
    
            sentences_textrank = sent_tokenize(summary.strip())
            #print("Length of the text rank: \n", len(sentences_textrank))
            #print('Sentences:--------------------------------------\n',sentences_textrank)

            word_embeddings_textrank = extract_word_vectors()
            #print('Word embeddings:-----------------------------------\n',len(word_embeddings_textrank))

            sentence_vectors_textrank = sentence_vector_representation(sentences_textrank, word_embeddings)
            #print('Sentence vectors of summary generated by textrank ---------------------------\n', len(sentence_vectors_textrank), sentence_vectors_textrank)
    
            similarity_matrix = cosine_similarity(sentence_vectors_textrank, sentence_vectors)
            max_similarity_indices = similarity_matrix.argmax(axis=1)
            #print(f'Length of Indices is: {len(max_similarity_indices)}')
            #print(f'Indices of comparision:{max_similarity_indices}')
            sentence_vectors_textrank=sorted(sentence_vectors_textrank, key=lambda x: x[0])
            summary_final = generate_summary_kmeans(sentences_textrank, sentence_vectors_textrank)
            #print('Summary generated by combining TextRank and K-means--------------------\n',summary_final)
            summary_filename = os.path.join(directory_path_write, filename.replace(".txt", "_1.txt"))
            with open(summary_filename, 'w', encoding='utf-8') as summary_file:
                summary_file.write(summary_final)
        print(f"Summary for '{filename}' written to '{summary_filename}'.")
    
            #plot_similarity_matrix(sim_mat,sentences)
    
            #rouge = evaluate.load('rouge')
            #candidates = [summary_final]
    
    #with open('17_1.txt', 'rt',encoding='utf-8') as file2:
    #    temp = file2.read()
    #    summary_one = temp
        
        
    #with open('17_2.txt', 'rt',encoding='utf-8') as file3:
    #   temp = file3.read()
    #    summary_two = temp
        
    #with open('17_3.txt', 'rt',encoding='utf-8') as file4:
    #    temp = file4.read()
    #    summary_three = temp
    
    #with open('17_4.txt', 'rt',encoding='utf-8') as file5:
    #    temp = file5.read()
    #    summary_four = temp

    #references1 = [summary_one]
    #references2 = [summary_two]
    #references3 = [summary_three]
    #references4 = [summary_four]

    #results1 = rouge.compute(predictions=candidates, references=references1)
    #results2 = rouge.compute(predictions=candidates, references=references2)
    #results3 = rouge.compute(predictions=candidates, references=references3)
    #results4 = rouge.compute(predictions=candidates, references=references4)
    
    #results=[results1,results2,results3,results4]
    #data_frame= pd.DataFrame(results,index=['Summary1_Scores','Summary2_Scores','Summary3_Scores','Summary4_Scores'])
    #print("The Results of checking with combination of TextRank and K-means:")
    #print(data_frame,'\n')
    
    #candidates1=[summary]
    
    #references1 = [summary_one]
    #references2 = [summary_two]
    #references3 = [summary_three]
    #references4 = [summary_four]

    #results1 = rouge.compute(predictions=candidates1, references=references1)
    #results2 = rouge.compute(predictions=candidates1, references=references2)
    #results3 = rouge.compute(predictions=candidates1, references=references3)
    #results4 = rouge.compute(predictions=candidates1, references=references4)
    
    #results=[results1,results2,results3,results4]
    #data_frame= pd.DataFrame(results,index=['Summary1_Scores','Summary2_Scores','Summary3_Scores','Summary4_Scores'])
    #print("The Results of checking with only TextRank:")
    #print(data_frame,'\n')
        
#def plot_similarity_matrix(similarity_matrix, labels, max_sentences=10):
#    #create labels for sentences
#    labels= [f"Sentences {i}" for i in range(1,max_sentences+1)]
    #Select the top 'max_sentences' sentences
#    top_similarity_matrix = similarity_matrix[:max_sentences,:max_sentences]
    
    # Create a heatmap
#    sns.set(font_scale=1)
#    plt.figure(figsize=(10,10))
#    ax = sns.heatmap(top_similarity_matrix, annot=True, cmap="PRGn", xticklabels=labels, yticklabels=labels)
    #Customize the plot
#    plt.title("Similarity Matrix of 10 sentences")
#    plt.xlabel("Sentences")
#    plt.ylabel("Sentences")
    #print('\nOriginal document-------------------------------------------------\n',text,end='\n'*2)
    #print('Summary------------------------------------------------------------------\n',len(summary_final))
    
    
if __name__ == "__main__":
    main()
# Out:
# WARNING:tensorflow:From C:\Users\user\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# No. of sentences in the kmeans:32
#
# Summary for '30855.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/30855_1.txt'.
# No. of sentences in the kmeans:34
#
# Summary for '30856.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/30856_1.txt'.
# No. of sentences in the kmeans:33
#
# Summary for '30858.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/30858_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '30866.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/30866_1.txt'.
# No. of sentences in the kmeans:33
#
# Summary for '30874.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/30874_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '30886.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/30886_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '30887.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/30887_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '30888.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/30888_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '30894.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/30894_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '30895.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/30895_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '30897.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/30897_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '30899.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/30899_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '30901.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/30901_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '30902.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/30902_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '30903.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/30903_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '30904.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/30904_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '30907.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/30907_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '30913.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/30913_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '30920.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/30920_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '30922.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/30922_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '30924.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/30924_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '30927.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/30927_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '30940.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/30940_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '30941.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/30941_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '30943.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/30943_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '30946.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/30946_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '30947.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/30947_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '30948.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/30948_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '30950.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/30950_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '30952.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/30952_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '30954.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/30954_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '30960.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/30960_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '30962.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/30962_1.txt'.
# No. of sentences in the kmeans:33
#
# Summary for '30965.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/30965_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '30966.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/30966_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '30967.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/30967_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '30968.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/30968_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '30982.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/30982_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '30991.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/30991_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31005.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31005_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31007.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31007_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31008.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31008_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31012.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31012_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31013.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31013_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31014.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31014_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31015.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31015_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31022.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31022_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31023.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31023_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31026.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31026_1.txt'.
# No. of sentences in the kmeans:34
#
# Summary for '31031.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31031_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31033.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31033_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31034.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31034_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31036.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31036_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31037.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31037_1.txt'.
# No. of sentences in the kmeans:30
#
# Summary for '31038.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31038_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31040.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31040_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31042.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31042_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31050.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31050_1.txt'.
# No. of sentences in the kmeans:33
#
# Summary for '31053.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31053_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31058.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31058_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31059.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31059_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31061.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31061_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31063.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31063_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31064.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31064_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31074.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31074_1.txt'.
# No. of sentences in the kmeans:33
#
# Summary for '31076.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31076_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31101.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31101_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31105.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31105_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31109.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31109_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31114.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31114_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31127.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31127_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31146.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31146_1.txt'.
# No. of sentences in the kmeans:34
#
# Summary for '31165.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31165_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31201.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31201_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31202.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31202_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31203.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31203_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31204.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31204_1.txt'.
# No. of sentences in the kmeans:33
#
# Summary for '31220.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31220_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31224.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31224_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31242.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31242_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31254.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31254_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31260.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31260_1.txt'.
# No. of sentences in the kmeans:33
#
# Summary for '31265.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31265_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31271.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31271_1.txt'.
# No. of sentences in the kmeans:35
#
# Summary for '31274.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31274_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31277.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31277_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31290.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31290_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31292.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31292_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31306.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31306_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31315.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31315_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31316.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31316_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31319.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31319_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31329.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31329_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31333.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31333_1.txt'.
# No. of sentences in the kmeans:36
#
# Summary for '31336.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31336_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31358.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31358_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31363.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31363_1.txt'.
# No. of sentences in the kmeans:33
#
# Summary for '31383.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31383_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31399.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31399_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31424.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31424_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31440.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31440_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31452.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31452_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31462.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31462_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31469.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31469_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31474.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31474_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31478.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31478_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31484.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31484_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31492.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31492_1.txt'.
# No. of sentences in the kmeans:34
#
# Summary for '31506.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31506_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31508.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31508_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31509.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31509_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31512.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31512_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31513.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31513_1.txt'.
# No. of sentences in the kmeans:33
#
# Summary for '31514.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31514_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31517.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31517_1.txt'.
# No. of sentences in the kmeans:33
#
# Summary for '31540.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31540_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31546.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31546_1.txt'.
# No. of sentences in the kmeans:33
#
# Summary for '31567.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31567_1.txt'.
# No. of sentences in the kmeans:33
#
# Summary for '31568.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31568_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31573.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31573_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31589.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31589_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31595.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31595_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31601.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31601_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31604.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31604_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31608.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31608_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31610.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31610_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31617.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31617_1.txt'.
# No. of sentences in the kmeans:33
#
# Summary for '31618.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31618_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31620.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31620_1.txt'.
# No. of sentences in the kmeans:34
#
# Summary for '31623.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31623_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31628.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31628_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31631.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31631_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31632.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31632_1.txt'.
# No. of sentences in the kmeans:68
#
# Summary for '31633.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31633_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31634.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31634_1.txt'.
# No. of sentences in the kmeans:33
#
# Summary for '31646.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31646_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31648.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31648_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31650.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31650_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31654.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31654_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31655.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31655_1.txt'.
# No. of sentences in the kmeans:30
#
# Summary for '31659.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31659_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31661.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31661_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31664.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31664_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31677.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31677_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31678.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31678_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31681.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31681_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31685.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31685_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31699.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31699_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31705.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31705_1.txt'.
# No. of sentences in the kmeans:33
#
# Summary for '31755.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31755_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31757.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31757_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31766.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31766_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31769.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31769_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31784.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31784_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31794.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31794_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31811.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31811_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31817.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31817_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31824.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31824_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31828.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31828_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31831.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31831_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31834.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31834_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31839.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31839_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31843.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31843_1.txt'.
# No. of sentences in the kmeans:33
#
# Summary for '31844.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31844_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31846.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31846_1.txt'.
# No. of sentences in the kmeans:33
#
# Summary for '31850.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31850_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31851.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31851_1.txt'.
# No. of sentences in the kmeans:33
#
# Summary for '31854.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31854_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31855.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31855_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31857.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31857_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31866.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31866_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31872.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31872_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31879.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31879_1.txt'.
# No. of sentences in the kmeans:31
#
# Summary for '31889.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31889_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31914.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31914_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31926.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31926_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31938.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31938_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31939.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31939_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31940.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31940_1.txt'.
# No. of sentences in the kmeans:30
#
# Summary for '31942.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31942_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31948.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31948_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31950.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31950_1.txt'.
# No. of sentences in the kmeans:34
#
# Summary for '31955.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31955_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31959.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31959_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31969.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31969_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31970.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31970_1.txt'.
# No. of sentences in the kmeans:34
#
# Summary for '31979.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31979_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31983.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31983_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '31984.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31984_1.txt'.
# No. of sentences in the kmeans:33
#
# Summary for '31987.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/31987_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32004.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32004_1.txt'.
# No. of sentences in the kmeans:31
#
# Summary for '32020.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32020_1.txt'.
# No. of sentences in the kmeans:33
#
# Summary for '32021.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32021_1.txt'.
# No. of sentences in the kmeans:33
#
# Summary for '32025.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32025_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32032.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32032_1.txt'.
# No. of sentences in the kmeans:31
#
# Summary for '32034.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32034_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32042.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32042_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32044.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32044_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32051.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32051_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32061.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32061_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32067.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32067_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32071.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32071_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32072.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32072_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32074.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32074_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32092.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32092_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32097.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32097_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32098.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32098_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32107.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32107_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32113.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32113_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32116.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32116_1.txt'.
# No. of sentences in the kmeans:34
#
# Summary for '32129.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32129_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32134.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32134_1.txt'.
# No. of sentences in the kmeans:33
#
# Summary for '32135.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32135_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32136.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32136_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32139.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32139_1.txt'.
# No. of sentences in the kmeans:33
#
# Summary for '32140.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32140_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32141.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32141_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32143.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32143_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32144.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32144_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32148.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32148_1.txt'.
# No. of sentences in the kmeans:34
#
# Summary for '32149.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32149_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32150.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32150_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32155.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32155_1.txt'.
# No. of sentences in the kmeans:33
#
# Summary for '32156.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32156_1.txt'.
# No. of sentences in the kmeans:33
#
# Summary for '32157.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32157_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32163.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32163_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32165.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32165_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32168.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32168_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32170.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32170_1.txt'.
# No. of sentences in the kmeans:33
#
# Summary for '32176.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32176_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32177.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32177_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32179.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32179_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32180.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32180_1.txt'.
# No. of sentences in the kmeans:33
#
# Summary for '32183.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32183_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32185.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32185_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32186.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32186_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32190.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32190_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32196.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32196_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32197.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32197_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32217.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32217_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32220.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32220_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32223.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32223_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32229.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32229_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32236.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32236_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32248.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32248_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32272.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32272_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32286.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32286_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32333.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32333_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32340.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32340_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32343.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32343_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32345.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32345_1.txt'.
# No. of sentences in the kmeans:33
#
# Summary for '32349.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32349_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32355.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32355_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32359.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32359_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32376.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32376_1.txt'.
# No. of sentences in the kmeans:33
#
# Summary for '32378.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32378_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32380.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32380_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32384.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32384_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32389.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32389_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32392.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32392_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32394.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32394_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32408.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32408_1.txt'.
# No. of sentences in the kmeans:33
#
# Summary for '32414.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32414_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32424.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32424_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32437.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32437_1.txt'.
# No. of sentences in the kmeans:36
#
# Summary for '32452.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32452_1.txt'.
# No. of sentences in the kmeans:33
#
# Summary for '32480.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32480_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32482.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32482_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32531.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32531_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32538.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32538_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32540.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32540_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32541.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32541_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32543.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32543_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32545.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32545_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32548.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32548_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32553.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32553_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32555.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32555_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32556.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32556_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32557.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32557_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32560.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32560_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32561.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32561_1.txt'.
# No. of sentences in the kmeans:33
#
# Summary for '32562.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32562_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32583.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32583_1.txt'.
# No. of sentences in the kmeans:33
#
# Summary for '32597.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32597_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32599.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32599_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32602.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32602_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32609.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32609_1.txt'.
# No. of sentences in the kmeans:33
#
# Summary for '32616.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32616_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32623.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32623_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32648.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32648_1.txt'.
# No. of sentences in the kmeans:30
#
# Summary for '32651.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32651_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32657.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32657_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32684.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32684_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32688.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32688_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32693.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32693_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32717.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32717_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32734.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32734_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32771.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32771_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32773.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32773_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32792.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32792_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32809.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32809_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32810.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32810_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32825.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32825_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32848.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32848_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32849.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32849_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32854.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32854_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32859.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32859_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32865.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32865_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32874.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32874_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32879.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32879_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32886.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32886_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32926.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32926_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32936.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32936_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32939.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32939_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32954.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32954_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32964.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32964_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '32966.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/32966_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '33018.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/33018_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '33027.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/33027_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '33029.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/33029_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '33035.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/33035_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '33036.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/33036_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '33037.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/33037_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '33038.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/33038_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '33039.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/33039_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '33053.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/33053_1.txt'.
# No. of sentences in the kmeans:33
#
# Summary for '33054.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/33054_1.txt'.
# No. of sentences in the kmeans:29
#
# Summary for '33057.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/33057_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '33070.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/33070_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '33083.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/33083_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '33090.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/33090_1.txt'.
# No. of sentences in the kmeans:33
#
# Summary for '33097.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/33097_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '33098.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/33098_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '33130.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/33130_1.txt'.
# No. of sentences in the kmeans:32
#
# Summary for '33154.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/33154_1.txt'.
# No. of sentences in the kmeans:33
#
# Summary for '33155.txt' written to 'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/G-summaries/33155_1.txt'.

# %%
##### Renaming Filename with taskname############

# %%
import os
import re

def move_and_rename_files(source_folder,destination_folder):
    # Ensure destination folder exists, create if not
    
    if not os.path.exists(destination_folder):
        os.makedirs(destination_folder)
      

    # Loop through files in the source folder
    for filename in os.listdir(source_folder):
        #print(source_folder)
        source_path = os.path.join(source_folder, filename)
        print(source_path)
        # Ensure it is a file (not a folder)
        if os.path.isfile(source_path):
            # Extract file name and extension
            fname, fext = os.path.splitext(filename)
            fname1 = fname.split('_')[0]
            # Construct the new name
            new_name = f'fns{fname1}_{fname1}{fext}'

            # Construct the destination path
            destination_path = os.path.join(destination_folder, new_name)

            # Move the file by renaming it
            os.rename(source_path, destination_path)
            print(f'Moved and renamed: {filename} to {new_name}')

# Replace these paths with your actual source and destination paths
source_path = r'C:/Users/user/Desktop/Text books/fns2020_dataset/validation/validation/annual_reports/'
destination_path = r'C:/Users/user/Desktop/Text books/fns2020_dataset/'

move_and_rename_files(source_path,destination_path)

# %%
##### Renaming Gold summaries Filename with taskname############

# %%
import os

def rename_files_with_prefix(folder_path, prefix):
    # Ensure the folder exists
    if not os.path.exists(folder_path):
        print(f"Error: Folder '{folder_path}' does not exist.")
        return

    # Iterate through files in the folder
    for filename in os.listdir(folder_path):
        old_path = os.path.join(folder_path, filename)

        # Check if it's a file
        if os.path.isfile(old_path):
            # Extract the numeric part from the filename
            numeric_part = ''.join(c for c in filename.split('_')[0] if c.isdigit())

            # Construct the new filename with the specified prefix and extracted numeric part
            new_filename = f'{prefix}{numeric_part}_{filename}'

            # Construct the new path
            new_path = os.path.join(folder_path, new_filename)

            # Rename the file
            os.rename(old_path, new_path)
            print(f'Renamed: {filename} to {new_filename}')

# Replace these values with your actual folder path and desired prefix
folder_path = r'C:\Users\user\Desktop\Text books\Topics in NLP\fns2020_dataset\validation\validation\gold_summaries'
prefix = 'fns'

rename_files_with_prefix(folder_path, prefix)

# %%
###### Running JAR file using command prompt###############

# %%
# to execute an external command
import subprocess

# Path to the Java executable
java_executable = "java"

# Path to the .jar file you want to run
jar_file = "C:/Users/user/Desktop/Text books/Topics in NLP/rouge2_v1.2.2_runnable/v1.2.2/rouge2-1.2.2.jar"

# Command to execute the .jar file
command = [java_executable, "-jar", jar_file]

# Run the command
process = subprocess.Popen(command, stdout=subprocess.PIPE, stderr=subprocess.PIPE)

# Wait for the process to finish and get the output
stdout, stderr = process.communicate()

# Print the output
print("Output:", stdout.decode())
print("Errors:", stderr.decode())
# Out:
# Output: 2024-02-10 10:56:24 INFO  SettingsUtil:33 - Using rouge.properties='C:\Users\user\PHD Work\rouge.properties'
# 2024-02-10 10:56:24 INFO  ROUGECalculator:203 - Working on fns32134 ngram=L
# 2024-02-10 10:56:25 INFO  ROUGECalculator:203 - Working on fns32134 ngram=1
# 2024-02-10 10:56:25 INFO  ROUGECalculator:203 - Working on fns32134 ngram=2
# 2024-02-10 10:56:25 INFO  ROUGECalculator:203 - Working on fns32134 ngram=SU4
# 2024-02-10 10:56:25 INFO  ROUGECalculator:203 - Working on fns32376 ngram=L
# 2024-02-10 10:56:25 INFO  ROUGECalculator:203 - Working on fns32376 ngram=1
# 2024-02-10 10:56:25 INFO  ROUGECalculator:203 - Working on fns32376 ngram=2
# 2024-02-10 10:56:25 INFO  ROUGECalculator:203 - Working on fns32376 ngram=SU4
# 2024-02-10 10:56:25 INFO  ROUGECalculator:203 - Working on fns30991 ngram=L
# 2024-02-10 10:56:25 INFO  ROUGECalculator:203 - Working on fns30991 ngram=1
# 2024-02-10 10:56:25 INFO  ROUGECalculator:203 - Working on fns30991 ngram=2
# 2024-02-10 10:56:25 INFO  ROUGECalculator:203 - Working on fns30991 ngram=SU4
# 2024-02-10 10:56:25 INFO  ROUGECalculator:203 - Working on fns32135 ngram=L
# 2024-02-10 10:56:26 INFO  ROUGECalculator:203 - Working on fns32135 ngram=1
# 2024-02-10 10:56:26 INFO  ROUGECalculator:203 - Working on fns32135 ngram=2
# 2024-02-10 10:56:26 INFO  ROUGECalculator:203 - Working on fns32135 ngram=SU4
# 2024-02-10 10:56:26 INFO  ROUGECalculator:203 - Working on fns32136 ngram=L
# 2024-02-10 10:56:27 INFO  ROUGECalculator:203 - Working on fns32136 ngram=1
# 2024-02-10 10:56:27 INFO  ROUGECalculator:203 - Working on fns32136 ngram=2
# 2024-02-10 10:56:27 INFO  ROUGECalculator:203 - Working on fns32136 ngram=SU4
# 2024-02-10 10:56:27 INFO  ROUGECalculator:203 - Working on fns32378 ngram=L
# 2024-02-10 10:56:27 INFO  ROUGECalculator:203 - Working on fns32378 ngram=1
# 2024-02-10 10:56:27 INFO  ROUGECalculator:203 - Working on fns32378 ngram=2
# 2024-02-10 10:56:27 INFO  ROUGECalculator:203 - Working on fns32378 ngram=SU4
# 2024-02-10 10:56:27 INFO  ROUGECalculator:203 - Working on fns32139 ngram=L
# 2024-02-10 10:56:28 INFO  ROUGECalculator:203 - Working on fns32139 ngram=1
# 2024-02-10 10:56:28 INFO  ROUGECalculator:203 - Working on fns32139 ngram=2
# 2024-02-10 10:56:28 INFO  ROUGECalculator:203 - Working on fns32139 ngram=SU4
# 2024-02-10 10:56:28 INFO  ROUGECalculator:203 - Working on fns32810 ngram=L
# 2024-02-10 10:56:28 INFO  ROUGECalculator:203 - Working on fns32810 ngram=1
# 2024-02-10 10:56:28 INFO  ROUGECalculator:203 - Working on fns32810 ngram=2
# 2024-02-10 10:56:28 INFO  ROUGECalculator:203 - Working on fns32810 ngram=SU4
# 2024-02-10 10:56:29 INFO  ROUGECalculator:203 - Working on fns31601 ngram=L
# 2024-02-10 10:56:29 INFO  ROUGECalculator:203 - Working on fns31601 ngram=1
# 2024-02-10 10:56:29 INFO  ROUGECalculator:203 - Working on fns31601 ngram=2
# 2024-02-10 10:56:29 INFO  ROUGECalculator:203 - Working on fns31601 ngram=SU4
# 2024-02-10 10:56:29 INFO  ROUGECalculator:203 - Working on fns31843 ngram=L
# 2024-02-10 10:56:29 INFO  ROUGECalculator:203 - Working on fns31843 ngram=1
# 2024-02-10 10:56:29 INFO  ROUGECalculator:203 - Working on fns31843 ngram=2
# 2024-02-10 10:56:29 INFO  ROUGECalculator:203 - Working on fns31843 ngram=SU4
# 2024-02-10 10:56:29 INFO  ROUGECalculator:203 - Working on fns31844 ngram=L
# 2024-02-10 10:56:30 INFO  ROUGECalculator:203 - Working on fns31844 ngram=1
# 2024-02-10 10:56:30 INFO  ROUGECalculator:203 - Working on fns31844 ngram=2
# 2024-02-10 10:56:30 INFO  ROUGECalculator:203 - Working on fns31844 ngram=SU4
# 2024-02-10 10:56:30 INFO  ROUGECalculator:203 - Working on fns30874 ngram=L
# 2024-02-10 10:56:30 INFO  ROUGECalculator:203 - Working on fns30874 ngram=1
# 2024-02-10 10:56:30 INFO  ROUGECalculator:203 - Working on fns30874 ngram=2
# 2024-02-10 10:56:30 INFO  ROUGECalculator:203 - Working on fns30874 ngram=SU4
# 2024-02-10 10:56:30 INFO  ROUGECalculator:203 - Working on fns31040 ngram=L
# 2024-02-10 10:56:30 INFO  ROUGECalculator:203 - Working on fns31040 ngram=1
# 2024-02-10 10:56:30 INFO  ROUGECalculator:203 - Working on fns31040 ngram=2
# 2024-02-10 10:56:30 INFO  ROUGECalculator:203 - Working on fns31040 ngram=SU4
# 2024-02-10 10:56:30 INFO  ROUGECalculator:203 - Working on fns31042 ngram=L
# 2024-02-10 10:56:31 INFO  ROUGECalculator:203 - Working on fns31042 ngram=1
# 2024-02-10 10:56:31 INFO  ROUGECalculator:203 - Working on fns31042 ngram=2
# 2024-02-10 10:56:31 INFO  ROUGECalculator:203 - Working on fns31042 ngram=SU4
# 2024-02-10 10:56:31 INFO  ROUGECalculator:203 - Working on fns31165 ngram=L
# 2024-02-10 10:56:31 INFO  ROUGECalculator:203 - Working on fns31165 ngram=1
# 2024-02-10 10:56:31 INFO  ROUGECalculator:203 - Working on fns31165 ngram=2
# 2024-02-10 10:56:31 INFO  ROUGECalculator:203 - Working on fns31165 ngram=SU4
# 2024-02-10 10:56:31 INFO  ROUGECalculator:203 - Working on fns31604 ngram=L
# 2024-02-10 10:56:31 INFO  ROUGECalculator:203 - Working on fns31604 ngram=1
# 2024-02-10 10:56:31 INFO  ROUGECalculator:203 - Working on fns31604 ngram=2
# 2024-02-10 10:56:32 INFO  ROUGECalculator:203 - Working on fns31604 ngram=SU4
# 2024-02-10 10:56:32 INFO  ROUGECalculator:203 - Working on fns31846 ngram=L
# 2024-02-10 10:56:32 INFO  ROUGECalculator:203 - Working on fns31846 ngram=1
# 2024-02-10 10:56:32 INFO  ROUGECalculator:203 - Working on fns31846 ngram=2
# 2024-02-10 10:56:32 INFO  ROUGECalculator:203 - Working on fns31846 ngram=SU4
# 2024-02-10 10:56:32 INFO  ROUGECalculator:203 - Working on fns32936 ngram=L
# 2024-02-10 10:56:33 INFO  ROUGECalculator:203 - Working on fns32936 ngram=1
# 2024-02-10 10:56:33 INFO  ROUGECalculator:203 - Working on fns32936 ngram=2
# 2024-02-10 10:56:33 INFO  ROUGECalculator:203 - Working on fns32936 ngram=SU4
# 2024-02-10 10:56:33 INFO  ROUGECalculator:203 - Working on fns31969 ngram=L
# 2024-02-10 10:56:33 INFO  ROUGECalculator:203 - Working on fns31969 ngram=1
# 2024-02-10 10:56:33 INFO  ROUGECalculator:203 - Working on fns31969 ngram=2
# 2024-02-10 10:56:33 INFO  ROUGECalculator:203 - Working on fns31969 ngram=SU4
# 2024-02-10 10:56:33 INFO  ROUGECalculator:203 - Working on fns31608 ngram=L
# 2024-02-10 10:56:34 INFO  ROUGECalculator:203 - Working on fns31608 ngram=1
# 2024-02-10 10:56:34 INFO  ROUGECalculator:203 - Working on fns31608 ngram=2
# 2024-02-10 10:56:34 INFO  ROUGECalculator:203 - Working on fns31608 ngram=SU4
# 2024-02-10 10:56:34 INFO  ROUGECalculator:203 - Working on fns32939 ngram=L
# 2024-02-10 10:56:34 INFO  ROUGECalculator:203 - Working on fns32939 ngram=1
# 2024-02-10 10:56:34 INFO  ROUGECalculator:203 - Working on fns32939 ngram=2
# 2024-02-10 10:56:34 INFO  ROUGECalculator:203 - Working on fns32939 ngram=SU4
# 2024-02-10 10:56:34 INFO  ROUGECalculator:203 - Working on fns31970 ngram=L
# 2024-02-10 10:56:35 INFO  ROUGECalculator:203 - Working on fns31970 ngram=1
# 2024-02-10 10:56:35 INFO  ROUGECalculator:203 - Working on fns31970 ngram=2
# 2024-02-10 10:56:35 INFO  ROUGECalculator:203 - Working on fns31970 ngram=SU4
# 2024-02-10 10:56:35 INFO  ROUGECalculator:203 - Working on fns32025 ngram=L
# 2024-02-10 10:56:35 INFO  ROUGECalculator:203 - Working on fns32025 ngram=1
# 2024-02-10 10:56:35 INFO  ROUGECalculator:203 - Working on fns32025 ngram=2
# 2024-02-10 10:56:35 INFO  ROUGECalculator:203 - Working on fns32025 ngram=SU4
# 2024-02-10 10:56:35 INFO  ROUGECalculator:203 - Working on fns31058 ngram=L
# 2024-02-10 10:56:36 INFO  ROUGECalculator:203 - Working on fns31058 ngram=1
# 2024-02-10 10:56:36 INFO  ROUGECalculator:203 - Working on fns31058 ngram=2
# 2024-02-10 10:56:36 INFO  ROUGECalculator:203 - Working on fns31058 ngram=SU4
# 2024-02-10 10:56:36 INFO  ROUGECalculator:203 - Working on fns31850 ngram=L
# 2024-02-10 10:56:36 INFO  ROUGECalculator:203 - Working on fns31850 ngram=1
# 2024-02-10 10:56:36 INFO  ROUGECalculator:203 - Working on fns31850 ngram=2
# 2024-02-10 10:56:37 INFO  ROUGECalculator:203 - Working on fns31850 ngram=SU4
# 2024-02-10 10:56:37 INFO  ROUGECalculator:203 - Working on fns32389 ngram=L
# 2024-02-10 10:56:37 INFO  ROUGECalculator:203 - Working on fns32389 ngram=1
# 2024-02-10 10:56:37 INFO  ROUGECalculator:203 - Working on fns32389 ngram=2
# 2024-02-10 10:56:37 INFO  ROUGECalculator:203 - Working on fns32389 ngram=SU4
# 2024-02-10 10:56:37 INFO  ROUGECalculator:203 - Working on fns31059 ngram=L
# 2024-02-10 10:56:37 INFO  ROUGECalculator:203 - Working on fns31059 ngram=1
# 2024-02-10 10:56:37 INFO  ROUGECalculator:203 - Working on fns31059 ngram=2
# 2024-02-10 10:56:37 INFO  ROUGECalculator:203 - Working on fns31059 ngram=SU4
# 2024-02-10 10:56:37 INFO  ROUGECalculator:203 - Working on fns31851 ngram=L
# 2024-02-10 10:56:38 INFO  ROUGECalculator:203 - Working on fns31851 ngram=1
# 2024-02-10 10:56:38 INFO  ROUGECalculator:203 - Working on fns31851 ngram=2
# 2024-02-10 10:56:38 INFO  ROUGECalculator:203 - Working on fns31851 ngram=SU4
# 2024-02-10 10:56:38 INFO  ROUGECalculator:203 - Working on fns32148 ngram=L
# 2024-02-10 10:56:38 INFO  ROUGECalculator:203 - Working on fns32148 ngram=1
# 2024-02-10 10:56:38 INFO  ROUGECalculator:203 - Working on fns32148 ngram=2
# 2024-02-10 10:56:38 INFO  ROUGECalculator:203 - Working on fns32148 ngram=SU4
# 2024-02-10 10:56:38 INFO  ROUGECalculator:203 - Working on fns31610 ngram=L
# 2024-02-10 10:56:39 INFO  ROUGECalculator:203 - Working on fns31610 ngram=1
# 2024-02-10 10:56:39 INFO  ROUGECalculator:203 - Working on fns31610 ngram=2
# 2024-02-10 10:56:39 INFO  ROUGECalculator:203 - Working on fns31610 ngram=SU4
# 2024-02-10 10:56:39 INFO  ROUGECalculator:203 - Working on fns32149 ngram=L
# 2024-02-10 10:56:39 INFO  ROUGECalculator:203 - Working on fns32149 ngram=1
# 2024-02-10 10:56:39 INFO  ROUGECalculator:203 - Working on fns32149 ngram=2
# 2024-02-10 10:56:39 INFO  ROUGECalculator:203 - Working on fns32149 ngram=SU4
# 2024-02-10 10:56:39 INFO  ROUGECalculator:203 - Working on fns31854 ngram=L
# 2024-02-10 10:56:39 INFO  ROUGECalculator:203 - Working on fns31854 ngram=1
# 2024-02-10 10:56:39 INFO  ROUGECalculator:203 - Working on fns31854 ngram=2
# 2024-02-10 10:56:39 INFO  ROUGECalculator:203 - Working on fns31854 ngram=SU4
# 2024-02-10 10:56:40 INFO  ROUGECalculator:203 - Working on fns31855 ngram=L
# 2024-02-10 10:56:40 INFO  ROUGECalculator:203 - Working on fns31855 ngram=1
# 2024-02-10 10:56:40 INFO  ROUGECalculator:203 - Working on fns31855 ngram=2
# 2024-02-10 10:56:40 INFO  ROUGECalculator:203 - Working on fns31855 ngram=SU4
# 2024-02-10 10:56:40 INFO  ROUGECalculator:203 - Working on fns30887 ngram=L
# 2024-02-10 10:56:40 INFO  ROUGECalculator:203 - Working on fns30887 ngram=1
# 2024-02-10 10:56:40 INFO  ROUGECalculator:203 - Working on fns30887 ngram=2
# 2024-02-10 10:56:40 INFO  ROUGECalculator:203 - Working on fns30887 ngram=SU4
# 2024-02-10 10:56:41 INFO  ROUGECalculator:203 - Working on fns31290 ngram=L
# 2024-02-10 10:56:41 INFO  ROUGECalculator:203 - Working on fns31290 ngram=1
# 2024-02-10 10:56:41 INFO  ROUGECalculator:203 - Working on fns31290 ngram=2
# 2024-02-10 10:56:41 INFO  ROUGECalculator:203 - Working on fns31290 ngram=SU4
# 2024-02-10 10:56:41 INFO  ROUGECalculator:203 - Working on fns30886 ngram=L
# 2024-02-10 10:56:41 INFO  ROUGECalculator:203 - Working on fns30886 ngram=1
# 2024-02-10 10:56:41 INFO  ROUGECalculator:203 - Working on fns30886 ngram=2
# 2024-02-10 10:56:41 INFO  ROUGECalculator:203 - Working on fns30886 ngram=SU4
# 2024-02-10 10:56:41 INFO  ROUGECalculator:203 - Working on fns32380 ngram=L
# 2024-02-10 10:56:41 INFO  ROUGECalculator:203 - Working on fns32380 ngram=1
# 2024-02-10 10:56:41 INFO  ROUGECalculator:203 - Working on fns32380 ngram=2
# 2024-02-10 10:56:42 INFO  ROUGECalculator:203 - Working on fns32380 ngram=SU4
# 2024-02-10 10:56:42 INFO  ROUGECalculator:203 - Working on fns31050 ngram=L
# 2024-02-10 10:56:42 INFO  ROUGECalculator:203 - Working on fns31050 ngram=1
# 2024-02-10 10:56:42 INFO  ROUGECalculator:203 - Working on fns31050 ngram=2
# 2024-02-10 10:56:42 INFO  ROUGECalculator:203 - Working on fns31050 ngram=SU4
# 2024-02-10 10:56:42 INFO  ROUGECalculator:203 - Working on fns31292 ngram=L
# 2024-02-10 10:56:42 INFO  ROUGECalculator:203 - Working on fns31292 ngram=1
# 2024-02-10 10:56:42 INFO  ROUGECalculator:203 - Working on fns31292 ngram=2
# 2024-02-10 10:56:42 INFO  ROUGECalculator:203 - Working on fns31292 ngram=SU4
# 2024-02-10 10:56:42 INFO  ROUGECalculator:203 - Working on fns32140 ngram=L
# 2024-02-10 10:56:43 INFO  ROUGECalculator:203 - Working on fns32140 ngram=1
# 2024-02-10 10:56:43 INFO  ROUGECalculator:203 - Working on fns32140 ngram=2
# 2024-02-10 10:56:43 INFO  ROUGECalculator:203 - Working on fns32140 ngram=SU4
# 2024-02-10 10:56:43 INFO  ROUGECalculator:203 - Working on fns32020 ngram=L
# 2024-02-10 10:56:43 INFO  ROUGECalculator:203 - Working on fns32020 ngram=1
# 2024-02-10 10:56:43 INFO  ROUGECalculator:203 - Working on fns32020 ngram=2
# 2024-02-10 10:56:43 INFO  ROUGECalculator:203 - Working on fns32020 ngram=SU4
# 2024-02-10 10:56:43 INFO  ROUGECalculator:203 - Working on fns32141 ngram=L
# 2024-02-10 10:56:44 INFO  ROUGECalculator:203 - Working on fns32141 ngram=1
# 2024-02-10 10:56:44 INFO  ROUGECalculator:203 - Working on fns32141 ngram=2
# 2024-02-10 10:56:44 INFO  ROUGECalculator:203 - Working on fns32141 ngram=SU4
# 2024-02-10 10:56:44 INFO  ROUGECalculator:203 - Working on fns31053 ngram=L
# 2024-02-10 10:56:44 INFO  ROUGECalculator:203 - Working on fns31053 ngram=1
# 2024-02-10 10:56:44 INFO  ROUGECalculator:203 - Working on fns31053 ngram=2
# 2024-02-10 10:56:44 INFO  ROUGECalculator:203 - Working on fns31053 ngram=SU4
# 2024-02-10 10:56:45 INFO  ROUGECalculator:203 - Working on fns32021 ngram=L
# 2024-02-10 10:56:45 INFO  ROUGECalculator:203 - Working on fns32021 ngram=1
# 2024-02-10 10:56:45 INFO  ROUGECalculator:203 - Working on fns32021 ngram=2
# 2024-02-10 10:56:45 INFO  ROUGECalculator:203 - Working on fns32021 ngram=SU4
# 2024-02-10 10:56:45 INFO  ROUGECalculator:203 - Working on fns32384 ngram=L
# 2024-02-10 10:56:46 INFO  ROUGECalculator:203 - Working on fns32384 ngram=1
# 2024-02-10 10:56:46 INFO  ROUGECalculator:203 - Working on fns32384 ngram=2
# 2024-02-10 10:56:46 INFO  ROUGECalculator:203 - Working on fns32384 ngram=SU4
# 2024-02-10 10:56:46 INFO  ROUGECalculator:203 - Working on fns32143 ngram=L
# 2024-02-10 10:56:47 INFO  ROUGECalculator:203 - Working on fns32143 ngram=1
# 2024-02-10 10:56:47 INFO  ROUGECalculator:203 - Working on fns32143 ngram=2
# 2024-02-10 10:56:47 INFO  ROUGECalculator:203 - Working on fns32143 ngram=SU4
# 2024-02-10 10:56:47 INFO  ROUGECalculator:203 - Working on fns32144 ngram=L
# 2024-02-10 10:56:47 INFO  ROUGECalculator:203 - Working on fns32144 ngram=1
# 2024-02-10 10:56:47 INFO  ROUGECalculator:203 - Working on fns32144 ngram=2
# 2024-02-10 10:56:47 INFO  ROUGECalculator:203 - Working on fns32144 ngram=SU4
# 2024-02-10 10:56:47 INFO  ROUGECalculator:203 - Working on fns30888 ngram=L
# 2024-02-10 10:56:48 INFO  ROUGECalculator:203 - Working on fns30888 ngram=1
# 2024-02-10 10:56:48 INFO  ROUGECalculator:203 - Working on fns30888 ngram=2
# 2024-02-10 10:56:48 INFO  ROUGECalculator:203 - Working on fns30888 ngram=SU4
# 2024-02-10 10:56:48 INFO  ROUGECalculator:203 - Working on fns31857 ngram=L
# 2024-02-10 10:56:48 INFO  ROUGECalculator:203 - Working on fns31857 ngram=1
# 2024-02-10 10:56:48 INFO  ROUGECalculator:203 - Working on fns31857 ngram=2
# 2024-02-10 10:56:48 INFO  ROUGECalculator:203 - Working on fns31857 ngram=SU4
# 2024-02-10 10:56:48 INFO  ROUGECalculator:203 - Working on fns32825 ngram=L
# 2024-02-10 10:56:49 INFO  ROUGECalculator:203 - Working on fns32825 ngram=1
# 2024-02-10 10:56:49 INFO  ROUGECalculator:203 - Working on fns32825 ngram=2
# 2024-02-10 10:56:49 INFO  ROUGECalculator:203 - Working on fns32825 ngram=SU4
# 2024-02-10 10:56:49 INFO  ROUGECalculator:203 - Working on fns31979 ngram=L
# 2024-02-10 10:56:49 INFO  ROUGECalculator:203 - Working on fns31979 ngram=1
# 2024-02-10 10:56:49 INFO  ROUGECalculator:203 - Working on fns31979 ngram=2
# 2024-02-10 10:56:49 INFO  ROUGECalculator:203 - Working on fns31979 ngram=SU4
# 2024-02-10 10:56:49 INFO  ROUGECalculator:203 - Working on fns31617 ngram=L
# 2024-02-10 10:56:49 INFO  ROUGECalculator:203 - Working on fns31617 ngram=1
# 2024-02-10 10:56:49 INFO  ROUGECalculator:203 - Working on fns31617 ngram=2
# 2024-02-10 10:56:49 INFO  ROUGECalculator:203 - Working on fns31617 ngram=SU4
# 2024-02-10 10:56:49 INFO  ROUGECalculator:203 - Working on fns31618 ngram=L
# 2024-02-10 10:56:50 INFO  ROUGECalculator:203 - Working on fns31618 ngram=1
# 2024-02-10 10:56:50 INFO  ROUGECalculator:203 - Working on fns31618 ngram=2
# 2024-02-10 10:56:50 INFO  ROUGECalculator:203 - Working on fns31618 ngram=SU4
# 2024-02-10 10:56:50 INFO  ROUGECalculator:203 - Working on fns31023 ngram=L
# 2024-02-10 10:56:51 INFO  ROUGECalculator:203 - Working on fns31023 ngram=1
# 2024-02-10 10:56:51 INFO  ROUGECalculator:203 - Working on fns31023 ngram=2
# 2024-02-10 10:56:51 INFO  ROUGECalculator:203 - Working on fns31023 ngram=SU4
# 2024-02-10 10:56:51 INFO  ROUGECalculator:203 - Working on fns31265 ngram=L
# 2024-02-10 10:56:51 INFO  ROUGECalculator:203 - Working on fns31265 ngram=1
# 2024-02-10 10:56:51 INFO  ROUGECalculator:203 - Working on fns31265 ngram=2
# 2024-02-10 10:56:51 INFO  ROUGECalculator:203 - Working on fns31265 ngram=SU4
# 2024-02-10 10:56:51 INFO  ROUGECalculator:203 - Working on fns32113 ngram=L
# 2024-02-10 10:56:52 INFO  ROUGECalculator:203 - Working on fns32113 ngram=1
# 2024-02-10 10:56:52 INFO  ROUGECalculator:203 - Working on fns32113 ngram=2
# 2024-02-10 10:56:52 INFO  ROUGECalculator:203 - Working on fns32113 ngram=SU4
# 2024-02-10 10:56:52 INFO  ROUGECalculator:203 - Working on fns32355 ngram=L
# 2024-02-10 10:56:52 INFO  ROUGECalculator:203 - Working on fns32355 ngram=1
# 2024-02-10 10:56:52 INFO  ROUGECalculator:203 - Working on fns32355 ngram=2
# 2024-02-10 10:56:52 INFO  ROUGECalculator:203 - Working on fns32355 ngram=SU4
# 2024-02-10 10:56:52 INFO  ROUGECalculator:203 - Working on fns32597 ngram=L
# 2024-02-10 10:56:52 INFO  ROUGECalculator:203 - Working on fns32597 ngram=1
# 2024-02-10 10:56:52 INFO  ROUGECalculator:203 - Working on fns32597 ngram=2
# 2024-02-10 10:56:52 INFO  ROUGECalculator:203 - Working on fns32597 ngram=SU4
# 2024-02-10 10:56:52 INFO  ROUGECalculator:203 - Working on fns31146 ngram=L
# 2024-02-10 10:56:52 INFO  ROUGECalculator:203 - Working on fns31146 ngram=1
# 2024-02-10 10:56:52 INFO  ROUGECalculator:203 - Working on fns31146 ngram=2
# 2024-02-10 10:56:52 INFO  ROUGECalculator:203 - Working on fns31146 ngram=SU4
# 2024-02-10 10:56:53 INFO  ROUGECalculator:203 - Working on fns31026 ngram=L
# 2024-02-10 10:56:53 INFO  ROUGECalculator:203 - Working on fns31026 ngram=1
# 2024-02-10 10:56:53 INFO  ROUGECalculator:203 - Working on fns31026 ngram=2
# 2024-02-10 10:56:53 INFO  ROUGECalculator:203 - Working on fns31026 ngram=SU4
# 2024-02-10 10:56:53 INFO  ROUGECalculator:203 - Working on fns32236 ngram=L
# 2024-02-10 10:56:53 INFO  ROUGECalculator:203 - Working on fns32236 ngram=1
# 2024-02-10 10:56:53 INFO  ROUGECalculator:203 - Working on fns32236 ngram=2
# 2024-02-10 10:56:53 INFO  ROUGECalculator:203 - Working on fns32236 ngram=SU4
# 2024-02-10 10:56:54 INFO  ROUGECalculator:203 - Working on fns32599 ngram=L
# 2024-02-10 10:56:54 INFO  ROUGECalculator:203 - Working on fns32599 ngram=1
# 2024-02-10 10:56:54 INFO  ROUGECalculator:203 - Working on fns32599 ngram=2
# 2024-02-10 10:56:54 INFO  ROUGECalculator:203 - Working on fns32599 ngram=SU4
# 2024-02-10 10:56:54 INFO  ROUGECalculator:203 - Working on fns31940 ngram=L
# 2024-02-10 10:56:54 INFO  ROUGECalculator:203 - Working on fns31940 ngram=1
# 2024-02-10 10:56:54 INFO  ROUGECalculator:203 - Working on fns31940 ngram=2
# 2024-02-10 10:56:54 INFO  ROUGECalculator:203 - Working on fns31940 ngram=SU4
# 2024-02-10 10:56:55 INFO  ROUGECalculator:203 - Working on fns32116 ngram=L
# 2024-02-10 10:56:55 INFO  ROUGECalculator:203 - Working on fns32116 ngram=1
# 2024-02-10 10:56:55 INFO  ROUGECalculator:203 - Working on fns32116 ngram=2
# 2024-02-10 10:56:55 INFO  ROUGECalculator:203 - Working on fns32116 ngram=SU4
# 2024-02-10 10:56:55 INFO  ROUGECalculator:203 - Working on fns32359 ngram=L
# 2024-02-10 10:56:55 INFO  ROUGECalculator:203 - Working on fns32359 ngram=1
# 2024-02-10 10:56:55 INFO  ROUGECalculator:203 - Working on fns32359 ngram=2
# 2024-02-10 10:56:55 INFO  ROUGECalculator:203 - Working on fns32359 ngram=SU4
# 2024-02-10 10:56:55 INFO  ROUGECalculator:203 - Working on fns31942 ngram=L
# 2024-02-10 10:56:56 INFO  ROUGECalculator:203 - Working on fns31942 ngram=1
# 2024-02-10 10:56:56 INFO  ROUGECalculator:203 - Working on fns31942 ngram=2
# 2024-02-10 10:56:56 INFO  ROUGECalculator:203 - Working on fns31942 ngram=SU4
# 2024-02-10 10:56:56 INFO  ROUGECalculator:203 - Working on fns30854 ngram=L
# 2024-02-10 10:56:56 INFO  ROUGECalculator:203 - Working on fns30854 ngram=1
# 2024-02-10 10:56:56 INFO  ROUGECalculator:203 - Working on fns30854 ngram=2
# 2024-02-10 10:56:56 INFO  ROUGECalculator:203 - Working on fns30854 ngram=SU4
# 2024-02-10 10:56:56 INFO  ROUGECalculator:203 - Working on fns30852 ngram=L
# 2024-02-10 10:56:57 INFO  ROUGECalculator:203 - Working on fns30852 ngram=1
# 2024-02-10 10:56:57 INFO  ROUGECalculator:203 - Working on fns30852 ngram=2
# 2024-02-10 10:56:57 INFO  ROUGECalculator:203 - Working on fns30852 ngram=SU4
# 2024-02-10 10:56:57 INFO  ROUGECalculator:203 - Working on fns31260 ngram=L
# 2024-02-10 10:56:57 INFO  ROUGECalculator:203 - Working on fns31260 ngram=1
# 2024-02-10 10:56:57 INFO  ROUGECalculator:203 - Working on fns31260 ngram=2
# 2024-02-10 10:56:57 INFO  ROUGECalculator:203 - Working on fns31260 ngram=SU4
# 2024-02-10 10:56:57 INFO  ROUGECalculator:203 - Working on fns30850 ngram=L
# 2024-02-10 10:56:58 INFO  ROUGECalculator:203 - Working on fns30850 ngram=1
# 2024-02-10 10:56:58 INFO  ROUGECalculator:203 - Working on fns30850 ngram=2
# 2024-02-10 10:56:58 INFO  ROUGECalculator:203 - Working on fns30850 ngram=SU4
# 2024-02-10 10:56:58 INFO  ROUGECalculator:203 - Working on fns31383 ngram=L
# 2024-02-10 10:56:58 INFO  ROUGECalculator:203 - Working on fns31383 ngram=1
# 2024-02-10 10:56:58 INFO  ROUGECalculator:203 - Working on fns31383 ngram=2
# 2024-02-10 10:56:58 INFO  ROUGECalculator:203 - Working on fns31383 ngram=SU4
# 2024-02-10 10:56:58 INFO  ROUGECalculator:203 - Working on fns31022 ngram=L
# 2024-02-10 10:56:59 INFO  ROUGECalculator:203 - Working on fns31022 ngram=1
# 2024-02-10 10:56:59 INFO  ROUGECalculator:203 - Working on fns31022 ngram=2
# 2024-02-10 10:56:59 INFO  ROUGECalculator:203 - Working on fns31022 ngram=SU4
# 2024-02-10 10:56:59 INFO  ROUGECalculator:203 - Working on fns30858 ngram=L
# 2024-02-10 10:56:59 INFO  ROUGECalculator:203 - Working on fns30858 ngram=1
# 2024-02-10 10:56:59 INFO  ROUGECalculator:203 - Working on fns30858 ngram=2
# 2024-02-10 10:56:59 INFO  ROUGECalculator:203 - Working on fns30858 ngram=SU4
# 2024-02-10 10:57:00 INFO  ROUGECalculator:203 - Working on fns30856 ngram=L
# 2024-02-10 10:57:00 INFO  ROUGECalculator:203 - Working on fns30856 ngram=1
# 2024-02-10 10:57:00 INFO  ROUGECalculator:203 - Working on fns30856 ngram=2
# 2024-02-10 10:57:00 INFO  ROUGECalculator:203 - Working on fns30856 ngram=SU4
# 2024-02-10 10:57:01 INFO  ROUGECalculator:203 - Working on fns30855 ngram=L
# 2024-02-10 10:57:01 INFO  ROUGECalculator:203 - Working on fns30855 ngram=1
# 2024-02-10 10:57:01 INFO  ROUGECalculator:203 - Working on fns30855 ngram=2
# 2024-02-10 10:57:01 INFO  ROUGECalculator:203 - Working on fns30855 ngram=SU4
# 2024-02-10 10:57:01 INFO  ROUGECalculator:203 - Working on fns31824 ngram=L
# 2024-02-10 10:57:01 INFO  ROUGECalculator:203 - Working on fns31824 ngram=1
# 2024-02-10 10:57:01 INFO  ROUGECalculator:203 - Working on fns31824 ngram=2
# 2024-02-10 10:57:01 INFO  ROUGECalculator:203 - Working on fns31824 ngram=SU4
# 2024-02-10 10:57:01 INFO  ROUGECalculator:203 - Working on fns31705 ngram=L
# 2024-02-10 10:57:02 INFO  ROUGECalculator:203 - Working on fns31705 ngram=1
# 2024-02-10 10:57:02 INFO  ROUGECalculator:203 - Working on fns31705 ngram=2
# 2024-02-10 10:57:02 INFO  ROUGECalculator:203 - Working on fns31705 ngram=SU4
# 2024-02-10 10:57:02 INFO  ROUGECalculator:203 - Working on fns31948 ngram=L
# 2024-02-10 10:57:02 INFO  ROUGECalculator:203 - Working on fns31948 ngram=1
# 2024-02-10 10:57:02 INFO  ROUGECalculator:203 - Working on fns31948 ngram=2
# 2024-02-10 10:57:02 INFO  ROUGECalculator:203 - Working on fns31948 ngram=SU4
# 2024-02-10 10:57:02 INFO  ROUGECalculator:203 - Working on fns31828 ngram=L
# 2024-02-10 10:57:02 INFO  ROUGECalculator:203 - Working on fns31828 ngram=1
# 2024-02-10 10:57:02 INFO  ROUGECalculator:203 - Working on fns31828 ngram=2
# 2024-02-10 10:57:02 INFO  ROUGECalculator:203 - Working on fns31828 ngram=SU4
# 2024-02-10 10:57:02 INFO  ROUGECalculator:203 - Working on fns31034 ngram=L
# 2024-02-10 10:57:03 INFO  ROUGECalculator:203 - Working on fns31034 ngram=1
# 2024-02-10 10:57:03 INFO  ROUGECalculator:203 - Working on fns31034 ngram=2
# 2024-02-10 10:57:03 INFO  ROUGECalculator:203 - Working on fns31034 ngram=SU4
# 2024-02-10 10:57:03 INFO  ROUGECalculator:203 - Working on fns31277 ngram=L
# 2024-02-10 10:57:03 INFO  ROUGECalculator:203 - Working on fns31277 ngram=1
# 2024-02-10 10:57:03 INFO  ROUGECalculator:203 - Working on fns31277 ngram=2
# 2024-02-10 10:57:03 INFO  ROUGECalculator:203 - Working on fns31277 ngram=SU4
# 2024-02-10 10:57:03 INFO  ROUGECalculator:203 - Working on fns31036 ngram=L
# 2024-02-10 10:57:04 INFO  ROUGECalculator:203 - Working on fns31036 ngram=1
# 2024-02-10 10:57:04 INFO  ROUGECalculator:203 - Working on fns31036 ngram=2
# 2024-02-10 10:57:04 INFO  ROUGECalculator:203 - Working on fns31036 ngram=SU4
# 2024-02-10 10:57:04 INFO  ROUGECalculator:203 - Working on fns31399 ngram=L
# 2024-02-10 10:57:04 INFO  ROUGECalculator:203 - Working on fns31399 ngram=1
# 2024-02-10 10:57:04 INFO  ROUGECalculator:203 - Working on fns31399 ngram=2
# 2024-02-10 10:57:05 INFO  ROUGECalculator:203 - Working on fns31399 ngram=SU4
# 2024-02-10 10:57:05 INFO  ROUGECalculator:203 - Working on fns32004 ngram=L
# 2024-02-10 10:57:05 INFO  ROUGECalculator:203 - Working on fns32004 ngram=1
# 2024-02-10 10:57:05 INFO  ROUGECalculator:203 - Working on fns32004 ngram=2
# 2024-02-10 10:57:05 INFO  ROUGECalculator:203 - Working on fns32004 ngram=SU4
# 2024-02-10 10:57:06 INFO  ROUGECalculator:203 - Working on fns30982 ngram=L
# 2024-02-10 10:57:06 INFO  ROUGECalculator:203 - Working on fns30982 ngram=1
# 2024-02-10 10:57:06 INFO  ROUGECalculator:203 - Working on fns30982 ngram=2
# 2024-02-10 10:57:06 INFO  ROUGECalculator:203 - Working on fns30982 ngram=SU4
# 2024-02-10 10:57:06 INFO  ROUGECalculator:203 - Working on fns31037 ngram=L
# 2024-02-10 10:57:06 INFO  ROUGECalculator:203 - Working on fns31037 ngram=1
# 2024-02-10 10:57:07 INFO  ROUGECalculator:203 - Working on fns31037 ngram=2
# 2024-02-10 10:57:07 INFO  ROUGECalculator:203 - Working on fns31037 ngram=SU4
# 2024-02-10 10:57:07 INFO  ROUGECalculator:203 - Working on fns31950 ngram=L
# 2024-02-10 10:57:07 INFO  ROUGECalculator:203 - Working on fns31950 ngram=1
# 2024-02-10 10:57:07 INFO  ROUGECalculator:203 - Working on fns31950 ngram=2
# 2024-02-10 10:57:07 INFO  ROUGECalculator:203 - Working on fns31950 ngram=SU4
# 2024-02-10 10:57:07 INFO  ROUGECalculator:203 - Working on fns31038 ngram=L
# 2024-02-10 10:57:08 INFO  ROUGECalculator:203 - Working on fns31038 ngram=1
# 2024-02-10 10:57:08 INFO  ROUGECalculator:203 - Working on fns31038 ngram=2
# 2024-02-10 10:57:08 INFO  ROUGECalculator:203 - Working on fns31038 ngram=SU4
# 2024-02-10 10:57:08 INFO  ROUGECalculator:203 - Working on fns32248 ngram=L
# 2024-02-10 10:57:09 INFO  ROUGECalculator:203 - Working on fns32248 ngram=1
# 2024-02-10 10:57:09 INFO  ROUGECalculator:203 - Working on fns32248 ngram=2
# 2024-02-10 10:57:09 INFO  ROUGECalculator:203 - Working on fns32248 ngram=SU4
# 2024-02-10 10:57:11 INFO  ROUGECalculator:203 - Working on fns31831 ngram=L
# 2024-02-10 10:57:11 INFO  ROUGECalculator:203 - Working on fns31831 ngram=1
# 2024-02-10 10:57:11 INFO  ROUGECalculator:203 - Working on fns31831 ngram=2
# 2024-02-10 10:57:11 INFO  ROUGECalculator:203 - Working on fns31831 ngram=SU4
# 2024-02-10 10:57:11 INFO  ROUGECalculator:203 - Working on fns32129 ngram=L
# 2024-02-10 10:57:12 INFO  ROUGECalculator:203 - Working on fns32129 ngram=1
# 2024-02-10 10:57:12 INFO  ROUGECalculator:203 - Working on fns32129 ngram=2
# 2024-02-10 10:57:12 INFO  ROUGECalculator:203 - Working on fns32129 ngram=SU4
# 2024-02-10 10:57:12 INFO  ROUGECalculator:203 - Working on fns32480 ngram=L
# 2024-02-10 10:57:12 INFO  ROUGECalculator:203 - Working on fns32480 ngram=1
# 2024-02-10 10:57:12 INFO  ROUGECalculator:203 - Working on fns32480 ngram=2
# 2024-02-10 10:57:12 INFO  ROUGECalculator:203 - Working on fns32480 ngram=SU4
# 2024-02-10 10:57:12 INFO  ROUGECalculator:203 - Working on fns31271 ngram=L
# 2024-02-10 10:57:12 INFO  ROUGECalculator:203 - Working on fns31271 ngram=1
# 2024-02-10 10:57:12 INFO  ROUGECalculator:203 - Working on fns31271 ngram=2
# 2024-02-10 10:57:12 INFO  ROUGECalculator:203 - Working on fns31271 ngram=SU4
# 2024-02-10 10:57:13 INFO  ROUGECalculator:203 - Working on fns32482 ngram=L
# 2024-02-10 10:57:13 INFO  ROUGECalculator:203 - Working on fns32482 ngram=1
# 2024-02-10 10:57:13 INFO  ROUGECalculator:203 - Working on fns32482 ngram=2
# 2024-02-10 10:57:13 INFO  ROUGECalculator:203 - Working on fns32482 ngram=SU4
# 2024-02-10 10:57:13 INFO  ROUGECalculator:203 - Working on fns31031 ngram=L
# 2024-02-10 10:57:14 INFO  ROUGECalculator:203 - Working on fns31031 ngram=1
# 2024-02-10 10:57:14 INFO  ROUGECalculator:203 - Working on fns31031 ngram=2
# 2024-02-10 10:57:14 INFO  ROUGECalculator:203 - Working on fns31031 ngram=SU4
# 2024-02-10 10:57:14 INFO  ROUGECalculator:203 - Working on fns31274 ngram=L
# 2024-02-10 10:57:14 INFO  ROUGECalculator:203 - Working on fns31274 ngram=1
# 2024-02-10 10:57:14 INFO  ROUGECalculator:203 - Working on fns31274 ngram=2
# 2024-02-10 10:57:14 INFO  ROUGECalculator:203 - Working on fns31274 ngram=SU4
# 2024-02-10 10:57:14 INFO  ROUGECalculator:203 - Working on fns31033 ngram=L
# 2024-02-10 10:57:15 INFO  ROUGECalculator:203 - Working on fns31033 ngram=1
# 2024-02-10 10:57:15 INFO  ROUGECalculator:203 - Working on fns31033 ngram=2
# 2024-02-10 10:57:15 INFO  ROUGECalculator:203 - Working on fns31033 ngram=SU4
# 2024-02-10 10:57:15 INFO  ROUGECalculator:203 - Working on fns30866 ngram=L
# 2024-02-10 10:57:15 INFO  ROUGECalculator:203 - Working on fns30866 ngram=1
# 2024-02-10 10:57:15 INFO  ROUGECalculator:203 - Working on fns30866 ngram=2
# 2024-02-10 10:57:15 INFO  ROUGECalculator:203 - Working on fns30866 ngram=SU4
# 2024-02-10 10:57:15 INFO  ROUGECalculator:203 - Working on fns31834 ngram=L
# 2024-02-10 10:57:16 INFO  ROUGECalculator:203 - Working on fns31834 ngram=1
# 2024-02-10 10:57:16 INFO  ROUGECalculator:203 - Working on fns31834 ngram=2
# 2024-02-10 10:57:16 INFO  ROUGECalculator:203 - Working on fns31834 ngram=SU4
# 2024-02-10 10:57:16 INFO  ROUGECalculator:203 - Working on fns31955 ngram=L
# 2024-02-10 10:57:16 INFO  ROUGECalculator:203 - Working on fns31955 ngram=1
# 2024-02-10 10:57:16 INFO  ROUGECalculator:203 - Working on fns31955 ngram=2
# 2024-02-10 10:57:16 INFO  ROUGECalculator:203 - Working on fns31955 ngram=SU4
# 2024-02-10 10:57:16 INFO  ROUGECalculator:203 - Working on fns32926 ngram=L
# 2024-02-10 10:57:17 INFO  ROUGECalculator:203 - Working on fns32926 ngram=1
# 2024-02-10 10:57:17 INFO  ROUGECalculator:203 - Working on fns32926 ngram=2
# 2024-02-10 10:57:17 INFO  ROUGECalculator:203 - Working on fns32926 ngram=SU4
# 2024-02-10 10:57:17 INFO  ROUGECalculator:203 - Working on fns31959 ngram=L
# 2024-02-10 10:57:17 INFO  ROUGECalculator:203 - Working on fns31959 ngram=1
# 2024-02-10 10:57:17 INFO  ROUGECalculator:203 - Working on fns31959 ngram=2
# 2024-02-10 10:57:17 INFO  ROUGECalculator:203 - Working on fns31959 ngram=SU4
# 2024-02-10 10:57:17 INFO  ROUGECalculator:203 - Working on fns31839 ngram=L
# 2024-02-10 10:57:17 INFO  ROUGECalculator:203 - Working on fns31839 ngram=1
# 2024-02-10 10:57:17 INFO  ROUGECalculator:203 - Working on fns31839 ngram=2
# 2024-02-10 10:57:17 INFO  ROUGECalculator:203 - Working on fns31839 ngram=SU4
# 2024-02-10 10:57:17 INFO  ROUGECalculator:203 - Working on fns32809 ngram=L
# 2024-02-10 10:57:18 INFO  ROUGECalculator:203 - Working on fns32809 ngram=1
# 2024-02-10 10:57:18 INFO  ROUGECalculator:203 - Working on fns32809 ngram=2
# 2024-02-10 10:57:18 INFO  ROUGECalculator:203 - Working on fns32809 ngram=SU4
# 2024-02-10 10:57:18 INFO  ROUGECalculator:203 - Working on fns32333 ngram=L
# 2024-02-10 10:57:18 INFO  ROUGECalculator:203 - Working on fns32333 ngram=1
# 2024-02-10 10:57:18 INFO  ROUGECalculator:203 - Working on fns32333 ngram=2
# 2024-02-10 10:57:18 INFO  ROUGECalculator:203 - Working on fns32333 ngram=SU4
# 2024-02-10 10:57:18 INFO  ROUGECalculator:203 - Working on fns30950 ngram=L
# 2024-02-10 10:57:18 INFO  ROUGECalculator:203 - Working on fns30950 ngram=1
# 2024-02-10 10:57:18 INFO  ROUGECalculator:203 - Working on fns30950 ngram=2
# 2024-02-10 10:57:18 INFO  ROUGECalculator:203 - Working on fns30950 ngram=SU4
# 2024-02-10 10:57:18 INFO  ROUGECalculator:203 - Working on fns31005 ngram=L
# 2024-02-10 10:57:19 INFO  ROUGECalculator:203 - Working on fns31005 ngram=1
# 2024-02-10 10:57:19 INFO  ROUGECalculator:203 - Working on fns31005 ngram=2
# 2024-02-10 10:57:19 INFO  ROUGECalculator:203 - Working on fns31005 ngram=SU4
# 2024-02-10 10:57:20 INFO  ROUGECalculator:203 - Working on fns31127 ngram=L
# 2024-02-10 10:57:20 INFO  ROUGECalculator:203 - Working on fns31127 ngram=1
# 2024-02-10 10:57:20 INFO  ROUGECalculator:203 - Working on fns31127 ngram=2
# 2024-02-10 10:57:20 INFO  ROUGECalculator:203 - Working on fns31127 ngram=SU4
# 2024-02-10 10:57:20 INFO  ROUGECalculator:203 - Working on fns30952 ngram=L
# 2024-02-10 10:57:20 INFO  ROUGECalculator:203 - Working on fns30952 ngram=1
# 2024-02-10 10:57:20 INFO  ROUGECalculator:203 - Working on fns30952 ngram=2
# 2024-02-10 10:57:20 INFO  ROUGECalculator:203 - Working on fns30952 ngram=SU4
# 2024-02-10 10:57:20 INFO  ROUGECalculator:203 - Working on fns31007 ngram=L
# 2024-02-10 10:57:21 INFO  ROUGECalculator:203 - Working on fns31007 ngram=1
# 2024-02-10 10:57:21 INFO  ROUGECalculator:203 - Working on fns31007 ngram=2
# 2024-02-10 10:57:21 INFO  ROUGECalculator:203 - Working on fns31007 ngram=SU4
# 2024-02-10 10:57:21 INFO  ROUGECalculator:203 - Working on fns32217 ngram=L
# 2024-02-10 10:57:21 INFO  ROUGECalculator:203 - Working on fns32217 ngram=1
# 2024-02-10 10:57:21 INFO  ROUGECalculator:203 - Working on fns32217 ngram=2
# 2024-02-10 10:57:22 INFO  ROUGECalculator:203 - Working on fns32217 ngram=SU4
# 2024-02-10 10:57:22 INFO  ROUGECalculator:203 - Working on fns31008 ngram=L
# 2024-02-10 10:57:22 INFO  ROUGECalculator:203 - Working on fns31008 ngram=1
# 2024-02-10 10:57:22 INFO  ROUGECalculator:203 - Working on fns31008 ngram=2
# 2024-02-10 10:57:22 INFO  ROUGECalculator:203 - Working on fns31008 ngram=SU4
# 2024-02-10 10:57:22 INFO  ROUGECalculator:203 - Working on fns30830 ngram=L
# 2024-02-10 10:57:23 INFO  ROUGECalculator:203 - Working on fns30830 ngram=1
# 2024-02-10 10:57:23 INFO  ROUGECalculator:203 - Working on fns30830 ngram=2
# 2024-02-10 10:57:23 INFO  ROUGECalculator:203 - Working on fns30830 ngram=SU4
# 2024-02-10 10:57:23 INFO  ROUGECalculator:203 - Working on fns32693 ngram=L
# 2024-02-10 10:57:23 INFO  ROUGECalculator:203 - Working on fns32693 ngram=1
# 2024-02-10 10:57:23 INFO  ROUGECalculator:203 - Working on fns32693 ngram=2
# 2024-02-10 10:57:23 INFO  ROUGECalculator:203 - Working on fns32693 ngram=SU4
# 2024-02-10 10:57:23 INFO  ROUGECalculator:203 - Working on fns31242 ngram=L
# 2024-02-10 10:57:24 INFO  ROUGECalculator:203 - Working on fns31242 ngram=1
# 2024-02-10 10:57:24 INFO  ROUGECalculator:203 - Working on fns31242 ngram=2
# 2024-02-10 10:57:24 INFO  ROUGECalculator:203 - Working on fns31242 ngram=SU4
# 2024-02-10 10:57:24 INFO  ROUGECalculator:203 - Working on fns31363 ngram=L
# 2024-02-10 10:57:24 INFO  ROUGECalculator:203 - Working on fns31363 ngram=1
# 2024-02-10 10:57:24 INFO  ROUGECalculator:203 - Working on fns31363 ngram=2
# 2024-02-10 10:57:24 INFO  ROUGECalculator:203 - Working on fns31363 ngram=SU4
# 2024-02-10 10:57:24 INFO  ROUGECalculator:203 - Working on fns31484 ngram=L
# 2024-02-10 10:57:25 INFO  ROUGECalculator:203 - Working on fns31484 ngram=1
# 2024-02-10 10:57:25 INFO  ROUGECalculator:203 - Working on fns31484 ngram=2
# 2024-02-10 10:57:25 INFO  ROUGECalculator:203 - Working on fns31484 ngram=SU4
# 2024-02-10 10:57:25 INFO  ROUGECalculator:203 - Working on fns32452 ngram=L
# 2024-02-10 10:57:25 INFO  ROUGECalculator:203 - Working on fns32452 ngram=1
# 2024-02-10 10:57:25 INFO  ROUGECalculator:203 - Working on fns32452 ngram=2
# 2024-02-10 10:57:25 INFO  ROUGECalculator:203 - Working on fns32452 ngram=SU4
# 2024-02-10 10:57:26 INFO  ROUGECalculator:203 - Working on fns30838 ngram=L
# 2024-02-10 10:57:26 INFO  ROUGECalculator:203 - Working on fns30838 ngram=1
# 2024-02-10 10:57:26 INFO  ROUGECalculator:203 - Working on fns30838 ngram=2
# 2024-02-10 10:57:26 INFO  ROUGECalculator:203 - Working on fns30838 ngram=SU4
# 2024-02-10 10:57:26 INFO  ROUGECalculator:203 - Working on fns30954 ngram=L
# 2024-02-10 10:57:26 INFO  ROUGECalculator:203 - Working on fns30954 ngram=1
# 2024-02-10 10:57:26 INFO  ROUGECalculator:203 - Working on fns30954 ngram=2
# 2024-02-10 10:57:26 INFO  ROUGECalculator:203 - Working on fns30954 ngram=SU4
# 2024-02-10 10:57:26 INFO  ROUGECalculator:203 - Working on fns31926 ngram=L
# 2024-02-10 10:57:27 INFO  ROUGECalculator:203 - Working on fns31926 ngram=1
# 2024-02-10 10:57:27 INFO  ROUGECalculator:203 - Working on fns31926 ngram=2
# 2024-02-10 10:57:27 INFO  ROUGECalculator:203 - Working on fns31926 ngram=SU4
# 2024-02-10 10:57:27 INFO  ROUGECalculator:203 - Working on fns31012 ngram=L
# 2024-02-10 10:57:28 INFO  ROUGECalculator:203 - Working on fns31012 ngram=1
# 2024-02-10 10:57:28 INFO  ROUGECalculator:203 - Working on fns31012 ngram=2
# 2024-02-10 10:57:28 INFO  ROUGECalculator:203 - Working on fns31012 ngram=SU4
# 2024-02-10 10:57:28 INFO  ROUGECalculator:203 - Working on fns31254 ngram=L
# 2024-02-10 10:57:28 INFO  ROUGECalculator:203 - Working on fns31254 ngram=1
# 2024-02-10 10:57:28 INFO  ROUGECalculator:203 - Working on fns31254 ngram=2
# 2024-02-10 10:57:28 INFO  ROUGECalculator:203 - Working on fns31254 ngram=SU4
# 2024-02-10 10:57:29 INFO  ROUGECalculator:203 - Working on fns32343 ngram=L
# 2024-02-10 10:57:29 INFO  ROUGECalculator:203 - Working on fns32343 ngram=1
# 2024-02-10 10:57:29 INFO  ROUGECalculator:203 - Working on fns32343 ngram=2
# 2024-02-10 10:57:29 INFO  ROUGECalculator:203 - Working on fns32343 ngram=SU4
# 2024-02-10 10:57:30 INFO  ROUGECalculator:203 - Working on fns31013 ngram=L
# 2024-02-10 10:57:30 INFO  ROUGECalculator:203 - Working on fns31013 ngram=1
# 2024-02-10 10:57:30 INFO  ROUGECalculator:203 - Working on fns31013 ngram=2
# 2024-02-10 10:57:30 INFO  ROUGECalculator:203 - Working on fns31013 ngram=SU4
# 2024-02-10 10:57:30 INFO  ROUGECalculator:203 - Working on fns32223 ngram=L
# 2024-02-10 10:57:31 INFO  ROUGECalculator:203 - Working on fns32223 ngram=1
# 2024-02-10 10:57:31 INFO  ROUGECalculator:203 - Working on fns32223 ngram=2
# 2024-02-10 10:57:31 INFO  ROUGECalculator:203 - Working on fns32223 ngram=SU4
# 2024-02-10 10:57:31 INFO  ROUGECalculator:203 - Working on fns31014 ngram=L
# 2024-02-10 10:57:31 INFO  ROUGECalculator:203 - Working on fns31014 ngram=1
# 2024-02-10 10:57:31 INFO  ROUGECalculator:203 - Working on fns31014 ngram=2
# 2024-02-10 10:57:31 INFO  ROUGECalculator:203 - Working on fns31014 ngram=SU4
# 2024-02-10 10:57:31 INFO  ROUGECalculator:203 - Working on fns32345 ngram=L
# 2024-02-10 10:57:32 INFO  ROUGECalculator:203 - Working on fns32345 ngram=1
# 2024-02-10 10:57:32 INFO  ROUGECalculator:203 - Working on fns32345 ngram=2
# 2024-02-10 10:57:32 INFO  ROUGECalculator:203 - Working on fns32345 ngram=SU4
# 2024-02-10 10:57:32 INFO  ROUGECalculator:203 - Working on fns30960 ngram=L
# 2024-02-10 10:57:32 INFO  ROUGECalculator:203 - Working on fns30960 ngram=1
# 2024-02-10 10:57:32 INFO  ROUGECalculator:203 - Working on fns30960 ngram=2
# 2024-02-10 10:57:32 INFO  ROUGECalculator:203 - Working on fns30960 ngram=SU4
# 2024-02-10 10:57:32 INFO  ROUGECalculator:203 - Working on fns31015 ngram=L
# 2024-02-10 10:57:33 INFO  ROUGECalculator:203 - Working on fns31015 ngram=1
# 2024-02-10 10:57:33 INFO  ROUGECalculator:203 - Working on fns31015 ngram=2
# 2024-02-10 10:57:33 INFO  ROUGECalculator:203 - Working on fns31015 ngram=SU4
# 2024-02-10 10:57:33 INFO  ROUGECalculator:203 - Working on fns30962 ngram=L
# 2024-02-10 10:57:34 INFO  ROUGECalculator:203 - Working on fns30962 ngram=1
# 2024-02-10 10:57:34 INFO  ROUGECalculator:203 - Working on fns30962 ngram=2
# 2024-02-10 10:57:34 INFO  ROUGECalculator:203 - Working on fns30962 ngram=SU4
# 2024-02-10 10:57:34 INFO  ROUGECalculator:203 - Working on fns32107 ngram=L
# 2024-02-10 10:57:34 INFO  ROUGECalculator:203 - Working on fns32107 ngram=1
# 2024-02-10 10:57:34 INFO  ROUGECalculator:203 - Working on fns32107 ngram=2
# 2024-02-10 10:57:34 INFO  ROUGECalculator:203 - Working on fns32107 ngram=SU4
# 2024-02-10 10:57:34 INFO  ROUGECalculator:203 - Working on fns32349 ngram=L
# 2024-02-10 10:57:35 INFO  ROUGECalculator:203 - Working on fns32349 ngram=1
# 2024-02-10 10:57:35 INFO  ROUGECalculator:203 - Working on fns32349 ngram=2
# 2024-02-10 10:57:35 INFO  ROUGECalculator:203 - Working on fns32349 ngram=SU4
# 2024-02-10 10:57:35 INFO  ROUGECalculator:203 - Working on fns31811 ngram=L
# 2024-02-10 10:57:35 INFO  ROUGECalculator:203 - Working on fns31811 ngram=1
# 2024-02-10 10:57:35 INFO  ROUGECalculator:203 - Working on fns31811 ngram=2
# 2024-02-10 10:57:35 INFO  ROUGECalculator:203 - Working on fns31811 ngram=SU4
# 2024-02-10 10:57:35 INFO  ROUGECalculator:203 - Working on fns32229 ngram=L
# 2024-02-10 10:57:35 INFO  ROUGECalculator:203 - Working on fns32229 ngram=1
# 2024-02-10 10:57:35 INFO  ROUGECalculator:203 - Working on fns32229 ngram=2
# 2024-02-10 10:57:35 INFO  ROUGECalculator:203 - Working on fns32229 ngram=SU4
# 2024-02-10 10:57:35 INFO  ROUGECalculator:203 - Working on fns30841 ngram=L
# 2024-02-10 10:57:36 INFO  ROUGECalculator:203 - Working on fns30841 ngram=1
# 2024-02-10 10:57:36 INFO  ROUGECalculator:203 - Working on fns30841 ngram=2
# 2024-02-10 10:57:36 INFO  ROUGECalculator:203 - Working on fns30841 ngram=SU4
# 2024-02-10 10:57:36 INFO  ROUGECalculator:203 - Working on fns31492 ngram=L
# 2024-02-10 10:57:36 INFO  ROUGECalculator:203 - Working on fns31492 ngram=1
# 2024-02-10 10:57:36 INFO  ROUGECalculator:203 - Working on fns31492 ngram=2
# 2024-02-10 10:57:36 INFO  ROUGECalculator:203 - Working on fns31492 ngram=SU4
# 2024-02-10 10:57:36 INFO  ROUGECalculator:203 - Working on fns32340 ngram=L
# 2024-02-10 10:57:37 INFO  ROUGECalculator:203 - Working on fns32340 ngram=1
# 2024-02-10 10:57:37 INFO  ROUGECalculator:203 - Working on fns32340 ngram=2
# 2024-02-10 10:57:37 INFO  ROUGECalculator:203 - Working on fns32340 ngram=SU4
# 2024-02-10 10:57:37 INFO  ROUGECalculator:203 - Working on fns32220 ngram=L
# 2024-02-10 10:57:37 INFO  ROUGECalculator:203 - Working on fns32220 ngram=1
# 2024-02-10 10:57:37 INFO  ROUGECalculator:203 - Working on fns32220 ngram=2
# 2024-02-10 10:57:37 INFO  ROUGECalculator:203 - Working on fns32220 ngram=SU4
# 2024-02-10 10:57:37 INFO  ROUGECalculator:203 - Working on fns32583 ngram=L
# 2024-02-10 10:57:38 INFO  ROUGECalculator:203 - Working on fns32583 ngram=1
# 2024-02-10 10:57:38 INFO  ROUGECalculator:203 - Working on fns32583 ngram=2
# 2024-02-10 10:57:38 INFO  ROUGECalculator:203 - Working on fns32583 ngram=SU4
# 2024-02-10 10:57:38 INFO  ROUGECalculator:203 - Working on fns30849 ngram=L
# 2024-02-10 10:57:38 INFO  ROUGECalculator:203 - Working on fns30849 ngram=1
# 2024-02-10 10:57:38 INFO  ROUGECalculator:203 - Working on fns30849 ngram=2
# 2024-02-10 10:57:38 INFO  ROUGECalculator:203 - Working on fns30849 ngram=SU4
# 2024-02-10 10:57:38 INFO  ROUGECalculator:203 - Working on fns30965 ngram=L
# 2024-02-10 10:57:39 INFO  ROUGECalculator:203 - Working on fns30965 ngram=1
# 2024-02-10 10:57:39 INFO  ROUGECalculator:203 - Working on fns30965 ngram=2
# 2024-02-10 10:57:39 INFO  ROUGECalculator:203 - Working on fns30965 ngram=SU4
# 2024-02-10 10:57:39 INFO  ROUGECalculator:203 - Working on fns30966 ngram=L
# 2024-02-10 10:57:39 INFO  ROUGECalculator:203 - Working on fns30966 ngram=1
# 2024-02-10 10:57:39 INFO  ROUGECalculator:203 - Working on fns30966 ngram=2
# 2024-02-10 10:57:39 INFO  ROUGECalculator:203 - Working on fns30966 ngram=SU4
# 2024-02-10 10:57:40 INFO  ROUGECalculator:203 - Working on fns30967 ngram=L
# 2024-02-10 10:57:40 INFO  ROUGECalculator:203 - Working on fns30967 ngram=1
# 2024-02-10 10:57:40 INFO  ROUGECalculator:203 - Working on fns30967 ngram=2
# 2024-02-10 10:57:40 INFO  ROUGECalculator:203 - Working on fns30967 ngram=SU4
# 2024-02-10 10:57:40 INFO  ROUGECalculator:203 - Working on fns30968 ngram=L
# 2024-02-10 10:57:40 INFO  ROUGECalculator:203 - Working on fns30968 ngram=1
# 2024-02-10 10:57:40 INFO  ROUGECalculator:203 - Working on fns30968 ngram=2
# 2024-02-10 10:57:40 INFO  ROUGECalculator:203 - Working on fns30968 ngram=SU4
# 2024-02-10 10:57:40 INFO  ROUGECalculator:203 - Working on fns31817 ngram=L
# 2024-02-10 10:57:41 INFO  ROUGECalculator:203 - Working on fns31817 ngram=1
# 2024-02-10 10:57:41 INFO  ROUGECalculator:203 - Working on fns31817 ngram=2
# 2024-02-10 10:57:41 INFO  ROUGECalculator:203 - Working on fns31817 ngram=SU4
# 2024-02-10 10:57:41 INFO  ROUGECalculator:203 - Working on fns31938 ngram=L
# 2024-02-10 10:57:41 INFO  ROUGECalculator:203 - Working on fns31938 ngram=1
# 2024-02-10 10:57:41 INFO  ROUGECalculator:203 - Working on fns31938 ngram=2
# 2024-02-10 10:57:41 INFO  ROUGECalculator:203 - Working on fns31938 ngram=SU4
# 2024-02-10 10:57:42 INFO  ROUGECalculator:203 - Working on fns31939 ngram=L
# 2024-02-10 10:57:42 INFO  ROUGECalculator:203 - Working on fns31939 ngram=1
# 2024-02-10 10:57:42 INFO  ROUGECalculator:203 - Working on fns31939 ngram=2
# 2024-02-10 10:57:43 INFO  ROUGECalculator:203 - Working on fns31939 ngram=SU4
# 2024-02-10 10:57:43 INFO  ROUGECalculator:203 - Working on fns31101 ngram=L
# 2024-02-10 10:57:43 INFO  ROUGECalculator:203 - Working on fns31101 ngram=1
# 2024-02-10 10:57:43 INFO  ROUGECalculator:203 - Working on fns31101 ngram=2
# 2024-02-10 10:57:43 INFO  ROUGECalculator:203 - Working on fns31101 ngram=SU4
# 2024-02-10 10:57:43 INFO  ROUGECalculator:203 - Working on fns32553 ngram=L
# 2024-02-10 10:57:44 INFO  ROUGECalculator:203 - Working on fns32553 ngram=1
# 2024-02-10 10:57:44 INFO  ROUGECalculator:203 - Working on fns32553 ngram=2
# 2024-02-10 10:57:44 INFO  ROUGECalculator:203 - Working on fns32553 ngram=SU4
# 2024-02-10 10:57:44 INFO  ROUGECalculator:203 - Working on fns31224 ngram=L
# 2024-02-10 10:57:44 INFO  ROUGECalculator:203 - Working on fns31224 ngram=1
# 2024-02-10 10:57:44 INFO  ROUGECalculator:203 - Working on fns31224 ngram=2
# 2024-02-10 10:57:44 INFO  ROUGECalculator:203 - Working on fns31224 ngram=SU4
# 2024-02-10 10:57:44 INFO  ROUGECalculator:203 - Working on fns32555 ngram=L
# 2024-02-10 10:57:45 INFO  ROUGECalculator:203 - Working on fns32555 ngram=1
# 2024-02-10 10:57:45 INFO  ROUGECalculator:203 - Working on fns32555 ngram=2
# 2024-02-10 10:57:45 INFO  ROUGECalculator:203 - Working on fns32555 ngram=SU4
# 2024-02-10 10:57:45 INFO  ROUGECalculator:203 - Working on fns32556 ngram=L
# 2024-02-10 10:57:45 INFO  ROUGECalculator:203 - Working on fns32556 ngram=1
# 2024-02-10 10:57:45 INFO  ROUGECalculator:203 - Working on fns32556 ngram=2
# 2024-02-10 10:57:45 INFO  ROUGECalculator:203 - Working on fns32556 ngram=SU4
# 2024-02-10 10:57:46 INFO  ROUGECalculator:203 - Working on fns31105 ngram=L
# 2024-02-10 10:57:46 INFO  ROUGECalculator:203 - Working on fns31105 ngram=1
# 2024-02-10 10:57:46 INFO  ROUGECalculator:203 - Working on fns31105 ngram=2
# 2024-02-10 10:57:46 INFO  ROUGECalculator:203 - Working on fns31105 ngram=SU4
# 2024-02-10 10:57:47 INFO  ROUGECalculator:203 - Working on fns31589 ngram=L
# 2024-02-10 10:57:47 INFO  ROUGECalculator:203 - Working on fns31589 ngram=1
# 2024-02-10 10:57:47 INFO  ROUGECalculator:203 - Working on fns31589 ngram=2
# 2024-02-10 10:57:47 INFO  ROUGECalculator:203 - Working on fns31589 ngram=SU4
# 2024-02-10 10:57:48 INFO  ROUGECalculator:203 - Working on fns32557 ngram=L
# 2024-02-10 10:57:48 INFO  ROUGECalculator:203 - Working on fns32557 ngram=1
# 2024-02-10 10:57:48 INFO  ROUGECalculator:203 - Working on fns32557 ngram=2
# 2024-02-10 10:57:48 INFO  ROUGECalculator:203 - Working on fns32557 ngram=SU4
# 2024-02-10 10:57:48 INFO  ROUGECalculator:203 - Working on fns31469 ngram=L
# ...
# ROUGE-2+StopWordRemoval	FNS32168	32168.TXT	Average_R:0.05571	Average_P:0.09539	Average_F:0.07034	Num Reference Summaries:3
#
#
# ROUGE-SU4+StopWordRemoval	FNS32168	32168.TXT	Average_R:0.09452	Average_P:0.16058	Average_F:0.11900	Num Reference Summaries:3
#
#
# ROUGE-L+StopWordRemoval	FNS31872	31872.TXT	Average_R:0.30190	Average_P:0.23184	Average_F:0.26227	Num Reference Summaries:4
#
#
# ROUGE-1+StopWordRemoval	FNS31872	31872.TXT	Average_R:0.37614	Average_P:0.30640	Average_F:0.33771	Num Reference Summaries:4
#
#
# ROUGE-2+StopWordRemoval	FNS31872	31872.TXT	Average_R:0.20230	Average_P:0.13283	Average_F:0.16037	Num Reference Summaries:4
#
#
# ROUGE-SU4+StopWordRemoval	FNS31872	31872.TXT	Average_R:0.31212	Average_P:0.17876	Average_F:0.22732	Num Reference Summaries:4
#
#
# ROUGE-L+StopWordRemoval	FNS31631	31631.TXT	Average_R:0.30631	Average_P:0.17832	Average_F:0.22542	Num Reference Summaries:3
#
#
# ROUGE-1+StopWordRemoval	FNS31631	31631.TXT	Average_R:0.33546	Average_P:0.22092	Average_F:0.26640	Num Reference Summaries:3
#
#
# ROUGE-2+StopWordRemoval	FNS31631	31631.TXT	Average_R:0.11417	Average_P:0.06813	Average_F:0.08533	Num Reference Summaries:3
#
#
# ROUGE-SU4+StopWordRemoval	FNS31631	31631.TXT	Average_R:0.19234	Average_P:0.10807	Average_F:0.13839	Num Reference Summaries:3
#
#
# ROUGE-L+StopWordRemoval	FNS31632	31632.TXT	Average_R:0.32566	Average_P:0.17518	Average_F:0.22781	Num Reference Summaries:4
#
#
# ROUGE-1+StopWordRemoval	FNS31632	31632.TXT	Average_R:0.36296	Average_P:0.25163	Average_F:0.29721	Num Reference Summaries:4
#
#
# ROUGE-2+StopWordRemoval	FNS31632	31632.TXT	Average_R:0.17314	Average_P:0.09008	Average_F:0.11851	Num Reference Summaries:4
#
#
# ROUGE-SU4+StopWordRemoval	FNS31632	31632.TXT	Average_R:0.24014	Average_P:0.12870	Average_F:0.16758	Num Reference Summaries:4
#
#
# ROUGE-L+StopWordRemoval	FNS31512	31512.TXT	Average_R:0.26958	Average_P:0.17202	Average_F:0.21003	Num Reference Summaries:4
#
#
# ROUGE-1+StopWordRemoval	FNS31512	31512.TXT	Average_R:0.32885	Average_P:0.22618	Average_F:0.26802	Num Reference Summaries:4
#
#
# ROUGE-2+StopWordRemoval	FNS31512	31512.TXT	Average_R:0.14703	Average_P:0.08501	Average_F:0.10774	Num Reference Summaries:4
#
#
# ROUGE-SU4+StopWordRemoval	FNS31512	31512.TXT	Average_R:0.23762	Average_P:0.11509	Average_F:0.15507	Num Reference Summaries:4
#
#
# ROUGE-L+StopWordRemoval	FNS31633	31633.TXT	Average_R:0.32432	Average_P:0.14756	Average_F:0.20283	Num Reference Summaries:4
#
#
# ROUGE-1+StopWordRemoval	FNS31633	31633.TXT	Average_R:0.41138	Average_P:0.14031	Average_F:0.20925	Num Reference Summaries:4
#
#
# ROUGE-2+StopWordRemoval	FNS31633	31633.TXT	Average_R:0.24303	Average_P:0.05278	Average_F:0.08672	Num Reference Summaries:4
#
#
# ROUGE-SU4+StopWordRemoval	FNS31633	31633.TXT	Average_R:0.32909	Average_P:0.07356	Average_F:0.12025	Num Reference Summaries:4
#
#
# ROUGE-L+StopWordRemoval	FNS32964	32964.TXT	Average_R:0.28716	Average_P:0.12721	Average_F:0.17631	Num Reference Summaries:4
#
#
# ROUGE-1+StopWordRemoval	FNS32964	32964.TXT	Average_R:0.40779	Average_P:0.16600	Average_F:0.23595	Num Reference Summaries:4
#
#
# ROUGE-2+StopWordRemoval	FNS32964	32964.TXT	Average_R:0.12773	Average_P:0.03918	Average_F:0.05997	Num Reference Summaries:4
#
#
# ROUGE-SU4+StopWordRemoval	FNS32964	32964.TXT	Average_R:0.24714	Average_P:0.07642	Average_F:0.11674	Num Reference Summaries:4
#
#
# ROUGE-L+StopWordRemoval	FNS33018	33018.TXT	Average_R:0.32283	Average_P:0.17468	Average_F:0.22669	Num Reference Summaries:3
#
#
# ROUGE-1+StopWordRemoval	FNS33018	33018.TXT	Average_R:0.32915	Average_P:0.23388	Average_F:0.27345	Num Reference Summaries:3
#
#
# ROUGE-2+StopWordRemoval	FNS33018	33018.TXT	Average_R:0.10927	Average_P:0.06563	Average_F:0.08201	Num Reference Summaries:3
#
#
# ROUGE-SU4+StopWordRemoval	FNS33018	33018.TXT	Average_R:0.20475	Average_P:0.11676	Average_F:0.14872	Num Reference Summaries:3
#
#
# ROUGE-L+StopWordRemoval	FNS31513	31513.TXT	Average_R:0.17803	Average_P:0.15775	Average_F:0.16728	Num Reference Summaries:3
#
#
# ROUGE-1+StopWordRemoval	FNS31513	31513.TXT	Average_R:0.17652	Average_P:0.17324	Average_F:0.17487	Num Reference Summaries:3
#
#
# ROUGE-2+StopWordRemoval	FNS31513	31513.TXT	Average_R:0.06441	Average_P:0.04493	Average_F:0.05293	Num Reference Summaries:3
#
#
# ROUGE-SU4+StopWordRemoval	FNS31513	31513.TXT	Average_R:0.10378	Average_P:0.08087	Average_F:0.09090	Num Reference Summaries:3
#
#
# ROUGE-L+StopWordRemoval	FNS31634	31634.TXT	Average_R:0.28454	Average_P:0.12729	Average_F:0.17589	Num Reference Summaries:4
#
#
# ROUGE-1+StopWordRemoval	FNS31634	31634.TXT	Average_R:0.32697	Average_P:0.18379	Average_F:0.23531	Num Reference Summaries:4
#
#
# ROUGE-2+StopWordRemoval	FNS31634	31634.TXT	Average_R:0.12106	Average_P:0.05346	Average_F:0.07417	Num Reference Summaries:4
#
#
# ROUGE-SU4+StopWordRemoval	FNS31634	31634.TXT	Average_R:0.19545	Average_P:0.09111	Average_F:0.12429	Num Reference Summaries:4
#
#
# ROUGE-L+StopWordRemoval	FNS31755	31755.TXT	Average_R:0.40009	Average_P:0.13387	Average_F:0.20061	Num Reference Summaries:4
#
#
# ROUGE-1+StopWordRemoval	FNS31755	31755.TXT	Average_R:0.42793	Average_P:0.16619	Average_F:0.23940	Num Reference Summaries:4
#
#
# ROUGE-2+StopWordRemoval	FNS31755	31755.TXT	Average_R:0.23523	Average_P:0.05246	Average_F:0.08579	Num Reference Summaries:4
#
#
# ROUGE-SU4+StopWordRemoval	FNS31755	31755.TXT	Average_R:0.33394	Average_P:0.08251	Average_F:0.13232	Num Reference Summaries:4
#
#
# ROUGE-L+StopWordRemoval	FNS32602	32602.TXT	Average_R:0.33133	Average_P:0.13823	Average_F:0.19507	Num Reference Summaries:6
#
#
# ROUGE-1+StopWordRemoval	FNS32602	32602.TXT	Average_R:0.42824	Average_P:0.11052	Average_F:0.17570	Num Reference Summaries:6
#
#
# ROUGE-2+StopWordRemoval	FNS32602	32602.TXT	Average_R:0.19650	Average_P:0.03446	Average_F:0.05864	Num Reference Summaries:6
#
#
# ROUGE-SU4+StopWordRemoval	FNS32602	32602.TXT	Average_R:0.29767	Average_P:0.04909	Average_F:0.08428	Num Reference Summaries:6
#
#
# ROUGE-L+StopWordRemoval	FNS31514	31514.TXT	Average_R:0.33137	Average_P:0.26824	Average_F:0.29648	Num Reference Summaries:4
#
#
# ROUGE-1+StopWordRemoval	FNS31514	31514.TXT	Average_R:0.34978	Average_P:0.31930	Average_F:0.33385	Num Reference Summaries:4
#
#
# ROUGE-2+StopWordRemoval	FNS31514	31514.TXT	Average_R:0.15458	Average_P:0.11107	Average_F:0.12926	Num Reference Summaries:4
#
#
# ROUGE-SU4+StopWordRemoval	FNS31514	31514.TXT	Average_R:0.22728	Average_P:0.14503	Average_F:0.17707	Num Reference Summaries:4
#
#
# ROUGE-L+StopWordRemoval	FNS32966	32966.TXT	Average_R:0.40477	Average_P:0.33671	Average_F:0.36762	Num Reference Summaries:3
#
#
# ROUGE-1+StopWordRemoval	FNS32966	32966.TXT	Average_R:0.42528	Average_P:0.38482	Average_F:0.40404	Num Reference Summaries:3
#
#
# ROUGE-2+StopWordRemoval	FNS32966	32966.TXT	Average_R:0.18764	Average_P:0.15315	Average_F:0.16865	Num Reference Summaries:3
#
#
# ROUGE-SU4+StopWordRemoval	FNS32966	32966.TXT	Average_R:0.29364	Average_P:0.20158	Average_F:0.23905	Num Reference Summaries:3
#
#
# ROUGE-L+StopWordRemoval	FNS33130	33130.TXT	Average_R:0.37741	Average_P:0.17764	Average_F:0.24158	Num Reference Summaries:3
#
#
# ROUGE-1+StopWordRemoval	FNS33130	33130.TXT	Average_R:0.44366	Average_P:0.23128	Average_F:0.30406	Num Reference Summaries:3
#
#
# ROUGE-2+StopWordRemoval	FNS33130	33130.TXT	Average_R:0.18255	Average_P:0.08812	Average_F:0.11887	Num Reference Summaries:3
#
#
# ROUGE-SU4+StopWordRemoval	FNS33130	33130.TXT	Average_R:0.24935	Average_P:0.13185	Average_F:0.17249	Num Reference Summaries:3
#
#
# ROUGE-L+StopWordRemoval	FNS30785	30785.TXT	Average_R:0.24355	Average_P:0.22108	Average_F:0.23178	Num Reference Summaries:4
#
#
# ROUGE-1+StopWordRemoval	FNS30785	30785.TXT	Average_R:0.25493	Average_P:0.25978	Average_F:0.25733	Num Reference Summaries:4
#
#
# ROUGE-2+StopWordRemoval	FNS30785	30785.TXT	Average_R:0.06606	Average_P:0.06623	Average_F:0.06615	Num Reference Summaries:4
#
#
# ROUGE-SU4+StopWordRemoval	FNS30785	30785.TXT	Average_R:0.13567	Average_P:0.11635	Average_F:0.12527	Num Reference Summaries:4
#
#
# ROUGE-L+StopWordRemoval	FNS31074	31074.TXT	Average_R:0.31360	Average_P:0.15812	Average_F:0.21024	Num Reference Summaries:3
#
#
# ROUGE-1+StopWordRemoval	FNS31074	31074.TXT	Average_R:0.36189	Average_P:0.18132	Average_F:0.24160	Num Reference Summaries:3
#
#
# ROUGE-2+StopWordRemoval	FNS31074	31074.TXT	Average_R:0.14983	Average_P:0.06492	Average_F:0.09059	Num Reference Summaries:3
#
#
# ROUGE-SU4+StopWordRemoval	FNS31074	31074.TXT	Average_R:0.22889	Average_P:0.08767	Average_F:0.12678	Num Reference Summaries:3
#
#
# ROUGE-L+StopWordRemoval	FNS32042	32042.TXT	Average_R:0.23349	Average_P:0.32454	Average_F:0.27159	Num Reference Summaries:3
#
#
# ROUGE-1+StopWordRemoval	FNS32042	32042.TXT	Average_R:0.16390	Average_P:0.39936	Average_F:0.23241	Num Reference Summaries:3
#
#
# ROUGE-2+StopWordRemoval	FNS32042	32042.TXT	Average_R:0.03740	Average_P:0.08763	Average_F:0.05242	Num Reference Summaries:3
#
#
# ROUGE-SU4+StopWordRemoval	FNS32042	32042.TXT	Average_R:0.07370	Average_P:0.16830	Average_F:0.10251	Num Reference Summaries:3
#
#
# ROUGE-L+StopWordRemoval	FNS32163	32163.TXT	Average_R:0.45155	Average_P:0.14758	Average_F:0.22246	Num Reference Summaries:3
#
#
# ROUGE-1+StopWordRemoval	FNS32163	32163.TXT	Average_R:0.50580	Average_P:0.15561	Average_F:0.23800	Num Reference Summaries:3
#
#
# ROUGE-2+StopWordRemoval	FNS32163	32163.TXT	Average_R:0.41516	Average_P:0.05676	Average_F:0.09987	Num Reference Summaries:3
#
#
# ROUGE-SU4+StopWordRemoval	FNS32163	32163.TXT	Average_R:0.45504	Average_P:0.08181	Average_F:0.13869	Num Reference Summaries:3
#
#
# ROUGE-L+StopWordRemoval	FNS30783	30783.TXT	Average_R:0.29991	Average_P:0.13485	Average_F:0.18604	Num Reference Summaries:3
#
#
# ROUGE-1+StopWordRemoval	FNS30783	30783.TXT	Average_R:0.37740	Average_P:0.13505	Average_F:0.19891	Num Reference Summaries:3
#
#
# ROUGE-2+StopWordRemoval	FNS30783	30783.TXT	Average_R:0.14705	Average_P:0.04740	Average_F:0.07169	Num Reference Summaries:3
#
#
# ROUGE-SU4+StopWordRemoval	FNS30783	30783.TXT	Average_R:0.24572	Average_P:0.07268	Average_F:0.11218	Num Reference Summaries:3
#
#
# ROUGE-L+StopWordRemoval	FNS30782	30782.TXT	Average_R:0.25972	Average_P:0.26040	Average_F:0.26006	Num Reference Summaries:3
#
#
# ROUGE-1+StopWordRemoval	FNS30782	30782.TXT	Average_R:0.25681	Average_P:0.29702	Average_F:0.27545	Num Reference Summaries:3
#
#
# ROUGE-2+StopWordRemoval	FNS30782	30782.TXT	Average_R:0.09445	Average_P:0.08389	Average_F:0.08886	Num Reference Summaries:3
#
#
# ROUGE-SU4+StopWordRemoval	FNS30782	30782.TXT	Average_R:0.15573	Average_P:0.14368	Average_F:0.14946	Num Reference Summaries:3
#
#
# ROUGE-L+StopWordRemoval	FNS31076	31076.TXT	Average_R:0.34488	Average_P:0.22727	Average_F:0.27399	Num Reference Summaries:3
#
#
# ROUGE-1+StopWordRemoval	FNS31076	31076.TXT	Average_R:0.41525	Average_P:0.22645	Average_F:0.29308	Num Reference Summaries:3
#
#
# ROUGE-2+StopWordRemoval	FNS31076	31076.TXT	Average_R:0.14369	Average_P:0.06980	Average_F:0.09396	Num Reference Summaries:3
#
#
# ROUGE-SU4+StopWordRemoval	FNS31076	31076.TXT	Average_R:0.26680	Average_P:0.10734	Average_F:0.15308	Num Reference Summaries:3
#
#
# ROUGE-L+StopWordRemoval	FNS32044	32044.TXT	Average_R:0.24991	Average_P:0.34359	Average_F:0.28936	Num Reference Summaries:5
#
#
# ROUGE-1+StopWordRemoval	FNS32044	32044.TXT	Average_R:0.26579	Average_P:0.44904	Average_F:0.33393	Num Reference Summaries:5
#
#
# ROUGE-2+StopWordRemoval	FNS32044	32044.TXT	Average_R:0.13277	Average_P:0.18636	Average_F:0.15507	Num Reference Summaries:5
#
#
# ROUGE-SU4+StopWordRemoval	FNS32044	32044.TXT	Average_R:0.19614	Average_P:0.26766	Average_F:0.22639	Num Reference Summaries:5
#
#
# ROUGE-L+StopWordRemoval	FNS32165	32165.TXT	Average_R:0.25241	Average_P:0.19509	Average_F:0.22008	Num Reference Summaries:3
#
#
# ROUGE-1+StopWordRemoval	FNS32165	32165.TXT	Average_R:0.27679	Average_P:0.23916	Average_F:0.25660	Num Reference Summaries:3
#
#
# ROUGE-2+StopWordRemoval	FNS32165	32165.TXT	Average_R:0.08957	Average_P:0.07040	Average_F:0.07884	Num Reference Summaries:3
#
#
# ROUGE-SU4+StopWordRemoval	FNS32165	32165.TXT	Average_R:0.13971	Average_P:0.10569	Average_F:0.12034	Num Reference Summaries:3
#
#
# ROUGE-L+StopWordRemoval	FNS32286	32286.TXT	Average_R:0.38370	Average_P:0.11374	Average_F:0.17547	Num Reference Summaries:4
#
#
# ROUGE-1+StopWordRemoval	FNS32286	32286.TXT	Average_R:0.45077	Average_P:0.08859	Average_F:0.14808	Num Reference Summaries:4
#
#
# ROUGE-2+StopWordRemoval	FNS32286	32286.TXT	Average_R:0.18798	Average_P:0.02687	Average_F:0.04702	Num Reference Summaries:4
#
#
# ROUGE-SU4+StopWordRemoval	FNS32286	32286.TXT	Average_R:0.29812	Average_P:0.03909	Average_F:0.06911	Num Reference Summaries:4
#
#
# ROUGE-L+StopWordRemoval	FNS30781	30781.TXT	Average_R:0.35900	Average_P:0.16515	Average_F:0.22623	Num Reference Summaries:4
#
#
# ROUGE-1+StopWordRemoval	FNS30781	30781.TXT	Average_R:0.42310	Average_P:0.15325	Average_F:0.22500	Num Reference Summaries:4
#
#
# ROUGE-2+StopWordRemoval	FNS30781	30781.TXT	Average_R:0.16112	Average_P:0.05580	Average_F:0.08289	Num Reference Summaries:4
#
#
# ROUGE-SU4+StopWordRemoval	FNS30781	30781.TXT	Average_R:0.25261	Average_P:0.07087	Average_F:0.11068	Num Reference Summaries:4
#
#
# ROUGE-L+StopWordRemoval	FNS31757	31757.TXT	Average_R:0.30291	Average_P:0.19855	Average_F:0.23987	Num Reference Summaries:4
#
#
# ROUGE-1+StopWordRemoval	FNS31757	31757.TXT	Average_R:0.35563	Average_P:0.26805	Average_F:0.30569	Num Reference Summaries:4
#
#
# ROUGE-2+StopWordRemoval	FNS31757	31757.TXT	Average_R:0.16853	Average_P:0.09296	Average_F:0.11983	Num Reference Summaries:4
#
#
# ROUGE-SU4+StopWordRemoval	FNS31757	31757.TXT	Average_R:0.25334	Average_P:0.13086	Average_F:0.17257	Num Reference Summaries:4
#
#
# ROUGE-L+StopWordRemoval	FNS31879	31879.TXT	Average_R:0.36179	Average_P:0.20450	Average_F:0.26130	Num Reference Summaries:4
#
#
# ROUGE-1+StopWordRemoval	FNS31879	31879.TXT	Average_R:0.47418	Average_P:0.24560	Average_F:0.32360	Num Reference Summaries:4
#
#
# ROUGE-2+StopWordRemoval	FNS31879	31879.TXT	Average_R:0.31140	Average_P:0.12770	Average_F:0.18113	Num Reference Summaries:4
#
#
# ROUGE-SU4+StopWordRemoval	FNS31879	31879.TXT	Average_R:0.35423	Average_P:0.13674	Average_F:0.19731	Num Reference Summaries:4
#
#
# ROUGE-L+StopWordRemoval	FNS31517	31517.TXT	Average_R:0.31525	Average_P:0.20674	Average_F:0.24972	Num Reference Summaries:4
#
#
# ROUGE-1+StopWordRemoval	FNS31517	31517.TXT	Average_R:0.37626	Average_P:0.24761	Average_F:0.29867	Num Reference Summaries:4
#
#
# ROUGE-2+StopWordRemoval	FNS31517	31517.TXT	Average_R:0.20566	Average_P:0.10892	Average_F:0.14241	Num Reference Summaries:4
#
#
# ROUGE-SU4+StopWordRemoval	FNS31517	31517.TXT	Average_R:0.27926	Average_P:0.13934	Average_F:0.18592	Num Reference Summaries:4
#
#
# ROUGE-L+StopWordRemoval	FNS32848	32848.TXT	Average_R:0.32939	Average_P:0.19765	Average_F:0.24706	Num Reference Summaries:3
#
#
# ROUGE-1+StopWordRemoval	FNS32848	32848.TXT	Average_R:0.40243	Average_P:0.21744	Average_F:0.28233	Num Reference Summaries:3
#
#
# ROUGE-2+StopWordRemoval	FNS32848	32848.TXT	Average_R:0.17016	Average_P:0.07391	Average_F:0.10306	Num Reference Summaries:3
#
#
# ROUGE-SU4+StopWordRemoval	FNS32848	32848.TXT	Average_R:0.27316	Average_P:0.10787	Average_F:0.15466	Num Reference Summaries:3
#
#
# ROUGE-L+StopWordRemoval	FNS32849	32849.TXT	Average_R:0.23632	Average_P:0.38295	Average_F:0.29228	Num Reference Summaries:3
#
#
# ROUGE-1+StopWordRemoval	FNS32849	32849.TXT	Average_R:0.22415	Average_P:0.48610	Average_F:0.30682	Num Reference Summaries:3
#
#
# ROUGE-2+StopWordRemoval	FNS32849	32849.TXT	Average_R:0.09696	Average_P:0.18399	Average_F:0.12700	Num Reference Summaries:3
#
#
# ROUGE-SU4+StopWordRemoval	FNS32849	32849.TXT	Average_R:0.15559	Average_P:0.25259	Average_F:0.19256	Num Reference Summaries:3
#
#
# ROUGE-L+StopWordRemoval	FNS32609	32609.TXT	Average_R:0.30937	Average_P:0.17521	Average_F:0.22372	Num Reference Summaries:3
#
#
# ROUGE-1+StopWordRemoval	FNS32609	32609.TXT	Average_R:0.36533	Average_P:0.18600	Average_F:0.24650	Num Reference Summaries:3
#
#
# ROUGE-2+StopWordRemoval	FNS32609	32609.TXT	Average_R:0.14065	Average_P:0.06313	Average_F:0.08714	Num Reference Summaries:3
#
#
# ROUGE-SU4+StopWordRemoval	FNS32609	32609.TXT	Average_R:0.21988	Average_P:0.09518	Average_F:0.13286	Num Reference Summaries:3
#
#
# ======Results Summary End======
#
# 2024-02-10 10:59:41 INFO  ROUGECalculator:269 - Results written to results.csv
#
#
# Done! Find results file in: C:\Users\user\PHD Work\results.csv
#
# Errors:

# %%
###### Calculating the Average Rouge Score for the generated ############

# %%
import pandas as pd

# Read the CSV file into a DataFrame
df = pd.read_csv("results.csv")

# Group the DataFrame by "ROUGE-Type" and calculate the averages for each group
averages_by_rouge_type = df.groupby("ROUGE-Type")[["Avg_Precision", "Avg_Recall", "Avg_F-Score"]].mean()

# Display the calculated averages
print("Averages for each ROUGE-Type:")
print(averages_by_rouge_type)
# Out:
# Averages for each ROUGE-Type:
#                            Avg_Precision  Avg_Recall  Avg_F-Score
# ROUGE-Type
# ROUGE-1+StopWordRemoval         0.229219    0.346082     0.262690
# ROUGE-2+StopWordRemoval         0.080570    0.149427     0.098990
# ROUGE-L+StopWordRemoval         0.196099    0.298000     0.230466
# ROUGE-SU4+StopWordRemoval       0.114745    0.223018     0.143899

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to C:\Users\KBS
# [nltk_data]     Iyer\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True
